# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Caio Monteiro Marquez Barbosa
# Felipe Bakowski Nantes de Souza
# Lucas Santos Teixeira

# %% [markdown]
# Atenção: Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# Carregando algumas bibliotecas:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# c:\Users\Felipe\Desktop\CdaDos_P1

# %% [markdown]
# Carregando a base de dados com os tweets classificados manualmente:

# %%
train = pd.read_excel('dados_treino.xlsx')
train.head(5)
# Out:
#                                             Mensagem  Unnamed: 1  Unnamed: 2  \
# 0  Um dos livros faltam mais de 40 páginas. Ex.: ...         NaN         NaN
# 1  O livro é incompleto. Acaba em 11/04/44, sendo...         NaN         NaN
# 2  Ainda não terminei, estou nos 40%, devo ler em...         NaN         NaN
# 3  Pedi o livro baseado na promoção q era de graç...         NaN         NaN
# 4  Prezados, Acredito que houve um erro, pois des...         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  ...  Unnamed: 87  Unnamed: 88  Unnamed: 89  Unnamed: 90  \
# 0         NaN  ...          NaN          NaN          NaN          NaN
# 1         NaN  ...          NaN          NaN          NaN          NaN
# 2         NaN  ...          NaN          NaN          NaN          NaN
# 3         NaN  ...          NaN          NaN          NaN          NaN
# 4         NaN  ...          NaN          NaN          NaN          NaN
#
#    Unnamed: 91  Unnamed: 92  Unnamed: 93  Unnamed: 94  Unnamed: 95    Target
# 0          NaN          NaN          NaN          NaN          NaN   entrega
# 1          NaN          NaN          NaN          NaN          NaN   entrega
# 2          NaN          NaN          NaN          NaN          NaN  conteúdo
# 3          NaN          NaN          NaN          NaN          NaN   entrega
# 4          NaN          NaN          NaN          NaN          NaN   entrega
#
# [5 rows x 97 columns]

# %%
test = pd.read_excel('dados_teste.xlsx')
test.head(5)
# Out:
#                                             Mensagem  Unnamed: 1  Unnamed: 2  \
# 0  a narrativa é muito lenta e você fica ansioso ...         NaN         NaN
# 1  Sim.adorei o livro Vou continuar a comprar o r...         NaN         NaN
# 2  Desculpem, mas achei deprimente e não me ensin...         NaN         NaN
# 3  Preciso saber se essa compra é do livro físico...         NaN         NaN
# 4  Embora tenha gostado do livro "Não Faz Sentido...         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  ...  Unnamed: 33  Unnamed: 34  Unnamed: 35 Unnamed: 36  \
# 0         NaN  ...          NaN          NaN          NaN         NaN
# 1         NaN  ...          NaN          NaN          NaN         NaN
# 2         NaN  ...          NaN          NaN          NaN         NaN
# 3         NaN  ...          NaN          NaN          NaN         NaN
# 4         NaN  ...          NaN          NaN          NaN         NaN
#
#    Unnamed: 37  Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41    Target
# 0          NaN          NaN          NaN          NaN          NaN  conteúdo
# 1          NaN          NaN          NaN          NaN          NaN  conteúdo
# 2          NaN          NaN          NaN          NaN          NaN  conteúdo
# 3          NaN          NaN          NaN          NaN          NaN   entrega
# 4          NaN          NaN          NaN          NaN          NaN  conteúdo
#
# [5 rows x 43 columns]

# %% [markdown]
# ___
# ## Classificador automático

# %% [markdown]
# Faça aqui uma descrição do seu assunto e o que considerou como relevante ou não relevante na classificação dos tweets (Target).
#
# ESCREVA AQUI...

# %% [markdown]
# ___
# ### Montando um Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %%
df_train = train['Mensagem'].to_frame()
df_train['Target'] = train['Target']

df_test = test['Mensagem'].to_frame()
df_test['Target'] = test['Target']

# %%
caracteres = [':',',','.','(',')', '?', '!', '"']
i = 0
for msg in df_train.Mensagem:
    for caractere in caracteres:
        if caractere in msg:
            msg = msg.replace(caractere, '')
            msg = msg.lower()
    df_train.loc[i, 'Mensagem'] = msg 
    i += 1
    
    
j = 0
for msg in df_test.Mensagem:
    for caractere in caracteres:
        if caractere in msg:
            msg = msg.replace(caractere, '')
            msg = msg.lower()
    df_test.loc[j, 'Mensagem'] = msg 
    j += 1

# %%
df_train.head(5)
# Out:
#                                             Mensagem    Target
# 0  um dos livros faltam mais de 40 páginas ex pul...   entrega
# 1  o livro é incompleto acaba em 11/04/44 sendo q...   entrega
# 2  ainda não terminei estou nos 40% devo ler em m...  conteúdo
# 3  pedi o livro baseado na promoção q era de graç...   entrega
# 4  prezados acredito que houve um erro pois desco...   entrega

# %%
df_test.head(5)
# Out:
#                                             Mensagem    Target
# 0  a narrativa é muito lenta e você fica ansioso ...  conteúdo
# 1  simadorei o livro vou continuar a comprar o re...  conteúdo
# 2  desculpem mas achei deprimente e não me ensino...  conteúdo
# 3  preciso saber se essa compra é do livro físico...   entrega
# 4  embora tenha gostado do livro não faz sentido ...  conteúdo

# %% [markdown]
# ___
# ### Verificando a performance do Classificador
#
# Agora você deve testar o seu classificador com a base de Testes.

# %%
lista_mensagem_teste = pd.Series(df_train.Mensagem) #pd series transforma em lista

# %%
#criando o conjunto universo de palavras
lista_mensagem_teste = pd.Series(df_train.Mensagem)

lista_dos_splits = []
for msg in lista_mensagem_teste:
    for palavra in msg.split():
        lista_dos_splits.append(palavra)


universo = list(set(lista_dos_splits))


print(universo)

print(len(universo))
# Out:
# ['atentei', 'subjacente', 'grave', 'importa', 'cobrando', 'visualização', '8000', 'riqueza', 'envolve', 'preço', 'crível', 'estilo', 'terá', 'novas', 'tensa', 'O', 'determinado', 'acréscimo', 'naquele', 'refencial', 'adiantes', 'fundamental', 'chata', 'ficcção', 'fazemos', 'preocupação', 'prestando', 'esteira', 'pensamentos', 'prejudicaram', 'valor', 'tendencioso', 'incrivel', 'xerox', 'atraso', 'ensinar', 'necessáriamente', 'politico', 'conseguiu', 'incapacidade', 'fonte', 'circo;', 'adoraria', 'afirma', 'auto-afirmativos', 'permitir', 'relevância', 'revisão', 'buscar', 'troca', 'caderno', 'induismo', 'potencial', 'cair', 'possivel', 'exclui', 'resumida', 'ultimos', 'vaidoso', 'extraviado', 'acessórios', 'obras', 'repetitiva', 'vazios', 'três', 'imitação', 'agrade', 'partirem', 'bastante', 'iria', 'compiladas', 'ouvir', '1973', 'manuseio', 'cristianismo', 'necessariamente', 'bonitas', 'veja', 'reduzido', 'graça', 'calvino', 'alienação', 'rasgada', 'título', 'excessivasisso', 'brancos', 'manipulação', 'dizer', 'discussão', 'vendido', 'nova', 'matou’', '15', 'conteúdos', 'arrazoado', 'werner', 'manada', 'piorou', 'emoções', 'reconhecerem', 'excelente', 'entender', 'eu', 'precariedade', 'maior', 'pessoas', 'tivesse', 'extremidades', 'só', 'interessados', 'ótimo', 'interessa', 'limite', 'mudar', 'fabulosamente', 'discurso', 'arrepender', 'marca', 'momento', 'uma', 'destópica', 'dava', 'descritas', 'fundadores', 'populações', 'pautas', 'compreender', 'venha', 'us$999', 'originalidade', 'inexperiente', 'encaminhando', 'passo-a-passoainda', 'escritora', 'concatenadas', 'levantar', 'site', 'verossímeis', 'estupro', 'crueldade', 'advogados', 'penhasco', 'desfecho', 'derivativo', 'frustrante', 'certas', 'consiga', 'ajuda', 'pô', 'apresentando-as', 'nosso', 'edicao', 'haja', 'encontraram', 'tirem', 'barulho', 'havido', 'impressas', 'conceito', 'funcionar', 'exemplares', 'vasto', 'faz', 'jargões', 'similares', 'ssseu', 'nós', 'as', 'saíam', 'devolvido', 'carreira', 'recortes', 'dono', 'meses', 'psicológica', 'haver', 'desenvolvam', 'demonstrou', 'desprazer', 'deturpada', 'originais', 'pai', 'ridícula', 'argumentar', 'relações', 'capa', 'domínio', 'honestamente', 'chamou', 'perfeitas', 'percebeu', 'estima', 'crianças', 'sensação', 'recuperar', 'volto', 'inicia', 'cosmologia', 'raras', 'óbvias', 'conhecimento', 'socialista', 'eróticos', '1964', 'bacana', 'toque', 'mosteiro', 'cabimento', 'história', 'volume', 'terminou', 'pedidos', 'imatura', 'informando', 'desagradaram', 'hipóteses', 'inteligente', 'prestado', 'fina', 'percebe-se', 'desnecessario', 'coloca', 'inúmeras', 'argumento', 'francês', 'personalidade', 'monstro', 'comentário', 'correto', 'maluca', 'lernão', 'promoçao', 'pirataria', 'heróis', 'falsificação', 'r$10000', 'crime', 'mudança', 'verdadeira', 'dentro', 'despertou', 'inferno', 'omitir', 'tentou', 'mão', 'haviam', 'imediatamente', 'usuário', 'ficou', 'muitas', 'frança', 'justificado', 'tais', 'compactada/pocket', 'ridículos', '1947', '2014', 'A', 'planck', 'afirmação', 'hoje', 'infinitamente', 'machucada', 'legal', 'escolhe', 'unidades', 'aproveitar', 'humorado', 'acaba', 'relatos', 'português', 'reafirmados', 'definitivamente', 'havendo', 'trinta', 'analisei', 'almeida', 'ameaça', 'peguei', 'rédeas', 'pergunta', 'retorno', 'demora', 'incontrolável', 'pensar', 'acho', 'americano', 'mundial', 'considero', 'conceitos', 'solicito', 'descontinuidade', 'paranoicos', 'informações', 'peça', 'interesse', 'linguagem', 'diagnóstico', 'medida', 'acabou', 'pura', 'claramente', 'dessa', 'abaixo', 'complicado', 'descobre', 'enchi', 'enaltecer', 'recebe', 'duplicadas', 'monumental', 'tanto', 'dizendo', 'cobrou', 'satisfeito', 'facebook', 'viria', 'pra', 'acabamento', 'bíblicas', 'ateísta', 'nesta', 'subúrbio', 'tremenda', 'ignaros', 'importante', 'profissão', 'chego', 'quais', 'venham', 'ratificar', 'botar', 'colocadas', 'dispositivo', 'portugues', 'entrada', 'infelizmente', 'problemas', 'informação', 'masculina', 'sacadas', 'fênix', 'loc ...
# 5097

# %%
#criando o conjunto de palavras de entrega
livro_conteudo = ''
df_train_conteudo = df_train.loc[(df_train.Target == 'conteúdo')]
for msg in df_train_conteudo.Mensagem:
    livro_conteudo += msg

# %%
livro_conteudo
# Out:
# "ainda não terminei estou nos 40% devo ler em mais uns dois dias mudando de opinião retifico o comentário salvo engano auto-ajuda da pior qualidade cheia de auto-elogios auto-referências a produtos e sites do autor escrito principalmente em primeira pessoa eu isso eu aquilo como eu sou bom cheio de contradições o autor começa contando como ele era um vendedor bem sucedido e no último ano de carreira resolveu se tornar o melhor da empresa já em referência futura ele afirma que era um fracassado até esse último ano em que foi o melhor vendedor da empresa curiosamente também não assume responsabilidade afirma que ficou devendo meio milhão de dólares pela crise de 2008 e não porque gastava demais ou era ruim no que fazia sempre há uma justificativa de quanto ele é bom e sabe das coisas e de como você é ruim se não quiser fazer o que ele propõe chega ao absurdo de dizer que se você afirmar antes de dormir que acordará disposto não faz diferença se dormir 3h da mesma forma que se dormir 9h e pensar que não vai acordar bem por alguma razão então não vai acordar bem mutatis mutandis tanto faz as horas de sono o que vale é seu pensamento positivo o assustador é esse livro possuir 45 estrelas e um coaching famosinho de concursos o indicar como mantra de mudança de vida só isso é um diagnóstico de quanto doente e ignorante é nossa sociedade atualbaixei o livro motivada pelo alto índice de avaliações  positivas  mas confesso que não encontrei nada  de  novo os livros hot seguem sempre a mesma linha homem fodão grosseiro e frio garota inexperiente que se envolve e se apaixona perdidamente e muito rapidamente pressão humilhação sexo sexo sexo traição mocinha sofrendo fodão se regenerando e felizes para sempre enfim nada de novoa mensagem do livro da pra entender em 1 página o resto é tudo enrolação e repetição desnecessária não comprem procure na wikipedia o principio de paretto que é o mesmo que ler esse livro que não consegui nem passar das primeiras paginastradução péssima os editores e o tradutor deviam se envergonhar sugiro aos interessados buscar uma edicao mais antiga em portugues em sebo ou adquirir a obra numa boa traducao em inglêsjá parei de ler história sem graçaachei um livro muito superficial e enfadonho o autor fica dando giros em volta de conceitos explicados muito por cima e a suposta receita nunca vem livros como a força do hábito são muito mais consistentesnão consegui chegar a metade texto chato não prendeu minha atenção de jeito nenhum me enchi da rachel ahei bem maçanteLivro com o nome baseado nas pessoas que compraram esse livronão consegui terminar a leitura achei superficial e infantil nem a abordagem sobre o toc conseguiu prender a atenção não recomendoo que um livro desse acrescenta ao conhecimento de um jovem nada e o pior é que há quem compreapresenta-se como um livro de auto-ajuda mas quando você começar a ler vai ver que se trata de um livro sobre a história do hábito assemelha-se mais a um livro didático de faculdade penso que se o objetivo era trazer a técnica para incorporar determinado hábito a nossa vida o livro poderia ser reduzido em até 75% a não ser que você seja um entusiasta que queria saber os primórdios do assunto não recomendomuito fraco e passional visão distorcida de direita não leria se soubesse que era tão ruim deveria se chamar guia politicamente incorreto e tacanhao livro é lindo edição maravilhosa mas demorei uma eternidade para terminar leitura difícil pesada muito detalhada e enrolada não despertou meu interesse em continuar a sérieo autor é fraquíssimo e escreve de maneira muito apelativa em uma vã tentativa de robustecer suas faláciaso mínimo que você precisa para não ser um idiota é não compar livros de olavo de carvalho que tem um pensamento e lógicas idiotas mas vende bastante o brasil está infestadoé uma revista diagramado como revista grampeado sem texto corrido um engano chamar d lê livro além disso conteúdo bobo sem pé nem cabeçavoltado especificamente aos usa um tanto repetitiv ...

# %%
livro_entrega = ''
df_train_entrega = df_train.loc[(df_train.Target == 'entrega')]
for msg in df_train_entrega.Mensagem:
    livro_entrega += msg

# %%
livro_entrega
# Out:
# "um dos livros faltam mais de 40 páginas ex pula da pág 140 pra pág 193 como foi um presente e a pessoa só viu quando estava lendo essa parte perdemos o prazo de devoluçãoo livro é incompleto acaba em 11/04/44 sendo que o diário dela foi escrito até 01/08/44 alguém pode explicar pq não informam que é incompletopedi o livro baseado na promoção q era de graça não autorizo está compra ajustem o site de vcs para evitar tais desconfortos dória tem razão e vcs não cumpriram com a palavra não aceito pagar r$2100 por este livro pois estava informando q era gratuitoprezados acredito que houve um erro pois descontaram o valor deste livro no meu cartão de crédito quando escolhi este livro foi no dia 30 de março no momento de uma campanha da empresa de doação de ebooks e este livro era uns dos livros disponíveis gratuitamente espero uma solução rápida pois não gostaria de ser lesadoVeio amassado nas pontasoh amazon por favor atualiza essa edição está sem condição de ler faltam frases dos personagens diálogos tem pedaço do livro que não da nem pra entender o que está acontecendogostei do acabamento do livro porém podia ser em paginas amareladas o livro tem uma gama de palavras em outra língua e o glossário fica na parte de trás logo fica uma leitura não muito dinâmicano ato da minha compra na descrição do produto não constava que o mesmo era um livro de bolso muito pelo contrário as dimensões do produto eram outras se eu estivesse no endereço quando o produto foi entregue teria devolvido o mesmo sem pestanejar infelizmente estava de férias e acabei perdendo o prazo de devolução outra observação que tenho a fazer é em relação ao zelo pelos produtos embalados os funcionários da amazon pesaram a mão nas minhas últimas entregas pois praticamente todos os livros contêm leves amassados em suas bordas fica aqui a minha indignação com a amazono pedido veio rápido os livros são maravilhosos porém o box veio em péssimas condições parece que caiu água nele e estufou todo o material como mostram as imagens as pontas estão destruídas com certeza caiu no chão em algum momento estou frustrada com a minha primeira aquisição na amazonentrega bem rápidamas tanto a caixaquanto as laterias dos livros vieram um pouco danificadascom pequenas marcaso plástico que vinha para protegertambém já estava um pouco rasgadoincrível como um e-book que custa us$999 na amazon internacional venha custando r$9000+ não entendo como conseguem vender com preços tão abusivoso volume 5 esta com erro tem impressão tem paginas duplicada e outras faltandoadquiri a edição comemorativa na verdade uma edição econômica extremamente mal feita 4a edição 2015 papel de baixa gramatura péssima encadernação as folhas estão desalinhadas há cola na lombada e a fonte utilizada bem  a fonte utlizada é um total desrespeito ao leitor muito pequena torna a leitura um esforço ao colocar esse produto no mercado a editora leya comete abuso um desrespeito aos leitores e à obra em si lamentável vergonhososupostamente baixei este livro gratis apos uma promoçao de vocês mas na verdade o download não foi realizado houvr algun problemabaixei a amostra e não consigo comprar a versão completa porque está indisponível entrei em contato com editora e fui informada que o problema está na página da loja amazon e que seria normalizado até o presente momento não houve mudança já tem dois meses que estou aguardando e aí amazon quando será normalizadocomprei no lançamento o livro e mais completo essa segunda edição tem paginas a menos em comparação ao outro faltou conteúdoachei muito merchandising e pouco conteúdo prático os conteúdos ficam em um site e não no livro sinto que desperdicei meu dinheiro com o livro já que no site o conteúdo é gratuito  além disso tem muitas histórias pessoais e relatos sobre como o milagre é incrível e pouco sobre o milagreeu também cheguei a entrar na página para comprar o livro em questão porém com avaliações como estas desisti da compra acho um absurdo uma empresa como a amazon estar e ...

# %%
livro_geral = livro_entrega + livro_conteudo

# %%
livro_geral
# Out:
# "um dos livros faltam mais de 40 páginas ex pula da pág 140 pra pág 193 como foi um presente e a pessoa só viu quando estava lendo essa parte perdemos o prazo de devoluçãoo livro é incompleto acaba em 11/04/44 sendo que o diário dela foi escrito até 01/08/44 alguém pode explicar pq não informam que é incompletopedi o livro baseado na promoção q era de graça não autorizo está compra ajustem o site de vcs para evitar tais desconfortos dória tem razão e vcs não cumpriram com a palavra não aceito pagar r$2100 por este livro pois estava informando q era gratuitoprezados acredito que houve um erro pois descontaram o valor deste livro no meu cartão de crédito quando escolhi este livro foi no dia 30 de março no momento de uma campanha da empresa de doação de ebooks e este livro era uns dos livros disponíveis gratuitamente espero uma solução rápida pois não gostaria de ser lesadoVeio amassado nas pontasoh amazon por favor atualiza essa edição está sem condição de ler faltam frases dos personagens diálogos tem pedaço do livro que não da nem pra entender o que está acontecendogostei do acabamento do livro porém podia ser em paginas amareladas o livro tem uma gama de palavras em outra língua e o glossário fica na parte de trás logo fica uma leitura não muito dinâmicano ato da minha compra na descrição do produto não constava que o mesmo era um livro de bolso muito pelo contrário as dimensões do produto eram outras se eu estivesse no endereço quando o produto foi entregue teria devolvido o mesmo sem pestanejar infelizmente estava de férias e acabei perdendo o prazo de devolução outra observação que tenho a fazer é em relação ao zelo pelos produtos embalados os funcionários da amazon pesaram a mão nas minhas últimas entregas pois praticamente todos os livros contêm leves amassados em suas bordas fica aqui a minha indignação com a amazono pedido veio rápido os livros são maravilhosos porém o box veio em péssimas condições parece que caiu água nele e estufou todo o material como mostram as imagens as pontas estão destruídas com certeza caiu no chão em algum momento estou frustrada com a minha primeira aquisição na amazonentrega bem rápidamas tanto a caixaquanto as laterias dos livros vieram um pouco danificadascom pequenas marcaso plástico que vinha para protegertambém já estava um pouco rasgadoincrível como um e-book que custa us$999 na amazon internacional venha custando r$9000+ não entendo como conseguem vender com preços tão abusivoso volume 5 esta com erro tem impressão tem paginas duplicada e outras faltandoadquiri a edição comemorativa na verdade uma edição econômica extremamente mal feita 4a edição 2015 papel de baixa gramatura péssima encadernação as folhas estão desalinhadas há cola na lombada e a fonte utilizada bem  a fonte utlizada é um total desrespeito ao leitor muito pequena torna a leitura um esforço ao colocar esse produto no mercado a editora leya comete abuso um desrespeito aos leitores e à obra em si lamentável vergonhososupostamente baixei este livro gratis apos uma promoçao de vocês mas na verdade o download não foi realizado houvr algun problemabaixei a amostra e não consigo comprar a versão completa porque está indisponível entrei em contato com editora e fui informada que o problema está na página da loja amazon e que seria normalizado até o presente momento não houve mudança já tem dois meses que estou aguardando e aí amazon quando será normalizadocomprei no lançamento o livro e mais completo essa segunda edição tem paginas a menos em comparação ao outro faltou conteúdoachei muito merchandising e pouco conteúdo prático os conteúdos ficam em um site e não no livro sinto que desperdicei meu dinheiro com o livro já que no site o conteúdo é gratuito  além disso tem muitas histórias pessoais e relatos sobre como o milagre é incrível e pouco sobre o milagreeu também cheguei a entrar na página para comprar o livro em questão porém com avaliações como estas desisti da compra acho um absurdo uma empresa como a amazon estar e ...

# %%
#estudo de frequência 
serie_geral = pd.Series(livro_geral.split())
tabela_geral = serie_geral.value_counts(True)
tabela_geral
# Out:
# de               0.033969
# o                0.032369
# que              0.031918
# e                0.030646
# a                0.029210
#                    ...
# curtia           0.000041
# encosta          0.000041
# contraditório    0.000041
# estudioso        0.000041
# psicológica      0.000041
# Length: 5364, dtype: float64

# %%
serie_conteudo = pd.Series(livro_conteudo.split())
tabela_conteudo = serie_conteudo.value_counts(True)
tabela_conteudo
# Out:
# de             0.037148
# que            0.033200
# e              0.031405
# o              0.030807
# a              0.028235
#                  ...
# 21             0.000060
# repassei       0.000060
# suposta        0.000060
# devolvi        0.000060
# psicológica    0.000060
# Length: 4222, dtype: float64

# %%
serie_entrega = pd.Series(livro_entrega.split())
tabela_entrega = serie_entrega.value_counts(True)
tabela_entrega
# Out:
# o                 0.035775
# a                 0.031336
# que               0.029116
# e                 0.028986
# de                0.027027
#                     ...
# painel            0.000131
# conspiração       0.000131
# mencionadas       0.000131
# personalidades    0.000131
# persistente       0.000131
# Length: 2042, dtype: float64

# %%
#suavização de laplace:
frequencia_suavizada = dict()
for palavra in (livro_geral.split()):
    D = len(livro_geral.split()) + len(universo)
    N = tabela_geral[palavra] + 1
    if palavra not in frequencia_suavizada:
        frequencia_suavizada[palavra] = N/D

    else:
        frequencia_suavizada[palavra] += N/D

# %%
frequencia_suavizada
# Out:
# {'um': 0.012255680837439841,
#  'dos': 0.0026209025863749014,
#  'livros': 0.003749199587961808,
#  'faltam': 0.00013574431359447646,
#  'mais': 0.004983526824243448,
#  'de': 0.029048809822099522,
#  '40': 0.00013574431359447646,
#  'páginas': 0.0010872017595144636,
#  'ex': 6.786658871349424e-05,
#  'pula': 6.786658871349424e-05,
#  'da': 0.007635727609343272,
#  'pág': 6.786658871349424e-05,
#  '140': 6.786658871349424e-05,
#  'pra': 0.0015637489907848222,
#  '193': 3.393190233581113e-05,
#  'como': 0.004708920070157851,
#  'foi': 0.003099203764024617,
#  'presente': 0.0004073665747932848,
#  'e': 0.026122851415685544,
#  'a': 0.024864200005568257,
#  'pessoa': 0.000373404047996882,
#  'só': 0.0018363066900526203,
#  'viu': 6.786658871349424e-05,
#  'quando': 0.001529691806564772,
#  'estava': 0.0009171385617639692,
#  'lendo': 0.0004752999805117068,
#  'essa': 0.0012913694701968323,
#  'parte': 0.0010191681282886492,
#  'perdemos': 3.393190233581113e-05,
#  'o': 0.027637734903532583,
#  'prazo': 0.00010180405913304936,
#  'devoluçãoo': 3.393190233581113e-05,
#  'livro': 0.01590258637489894,
#  'é': 0.013935126256298787,
#  'incompleto': 3.393190233581113e-05,
#  'acaba': 0.00016968735209777557,
#  'em': 0.008535003758456526,
#  '11/04/44': 3.393190233581113e-05,
#  'sendo': 0.0005092708594337259,
#  'que': 0.02724050502519515,
#  'diário': 0.0002375817812299897,
#  'dela': 0.0002375817812299897,
#  'escrito': 0.0005432445223976167,
#  'até': 0.001631871711350537,
#  '01/08/44': 3.393190233581113e-05,
#  'alguém': 0.0003394443052423508,
#  'pode': 0.0008831342743394862,
#  'explicar': 3.393190233581113e-05,
#  'pq': 0.00013574431359447646,
#  'não': 0.017383911022021796,
#  'informam': 6.786658871349424e-05,
#  'incompletopedi': 3.393190233581113e-05,
#  'baseado': 0.00016968735209777557,
#  'na': 0.00505220635318357,
#  'promoção': 0.0004752999805117068,
#  'q': 0.0004752999805117068,
#  'era': 0.0013254071661237775,
#  'graça': 0.0003394443052423508,
#  'autorizo': 3.393190233581113e-05,
#  'está': 0.0017000055680837425,
#  'compra': 0.0008151340516161361,
#  'ajustem': 3.393190233581113e-05,
#  'site': 0.0006112002004510151,
#  'vcs': 0.00013574431359447646,
#  'para': 0.008500381413736463,
#  'evitar': 3.393190233581113e-05,
#  'tais': 6.786658871349424e-05,
#  'desconfortos': 3.393190233581113e-05,
#  'dória': 3.393190233581113e-05,
#  'tem': 0.003030841615857906,
#  'razão': 0.00013574431359447646,
#  'cumpriram': 6.786658871349424e-05,
#  'com': 0.009193357276093396,
#  'palavra': 0.00013574431359447646,
#  'aceito': 3.393190233581113e-05,
#  'pagar': 0.0002715331718589048,
#  'r$2100': 3.393190233581113e-05,
#  'por': 0.004125972326623793,
#  'este': 0.0014275369581558497,
#  'pois': 0.001359447646092597,
#  'informando': 3.393190233581113e-05,
#  'gratuitoprezados': 3.393190233581113e-05,
#  'acredito': 0.00044133188563156,
#  'houve': 0.00010180405913304936,
#  'erro': 0.000373404047996882,
#  'descontaram': 3.393190233581113e-05,
#  'valor': 0.0007131545978451516,
#  'deste': 0.0005432445223976167,
#  'no': 0.005774013753166834,
#  'meu': 0.0017340766725131536,
#  'cartão': 0.00010180405913304936,
#  'crédito': 0.00010180405913304936,
#  'escolhi': 3.393190233581113e-05,
#  'dia': 0.0004752999805117068,
#  '30': 0.00010180405913304936,
#  'março': 3.393190233581113e-05,
#  'momento': 0.000373404047996882,
#  'uma': 0.007670280353016543,
#  'campanha': 3.393190233581113e-05,
#  'empresa': 0.00044133188563156,
#  'doação': 3.393190233581113e-05,
#  'ebooks': 0.00010180405913304936,
#  'uns': 0.00020363317464294664,
#  'disponíveis': 3.393190233581113e-05,
#  'gratuitamente': 0.00010180405913304936,
#  'espero': 0.0005092708594337259,
#  'solução': 0.00013574431359447646,
#  'rápida': 0.0002715331718589048,
#  'gostaria': 0.00044133188563156,
#  'ser': 0.0028599849661738877,
#  'lesadoVeio': 3.393190233581113e-05,
#  'amassado': 0.0002715331718589048,
#  'nas': 0.0007131545978451516,
#  'pontasoh': 3.393190233581113e-05,
#  'amazon': 0.0020408418942620896,
#  'favor': 6.786658871349424e-05,
#  'atualiza': 3.393190233581113e-05,
#  'edição': 0.0011212227511901776,
#  'sem': 0.0028941507280269463,
#  'condição': 3.393190233581113e-05,
#  'ler': 0.0028941507280269463,
#  'frases': 0.0003054873465296918,
#  'personagens': 0.000849132770956875,
#  'diálogos': 0.00016968735209777557,
#  'pedaço': 3.393190233581113e-05,
#  'do': 0.010200150338261167,
#  'nem': 0.0017000055680837425,
#  'entender': 0.0004073665747932848,
#  'acontecendogostei': 3.393190233581113e-05,
#  'acabamento': 3.393190233581113e-05,
#  'porém': 0.001257334558311757,
#  'podia': 0.00010180405913304936,
#  'paginas': 0.0002375817812299897,
#  'amareladas': 3.393190233581113e-05,
#  'gama': 3.393190233581113e-05,
#  'palavras': 0.0005092708594337259,
#  'outra': 0.00044133188563156,
#  'língua': 6.786658871349424e-05,
#  'glossário': 3.393190233581113e-05,
#  'fica': 0.0004073665747932848,
#  'trás': 0.00016968735209777557,
#  'logo': 0.00044133188563156,
#  'leitura': 0.0025526183913806067,
#  'muito': 0.005911640079066784,
#  'dinâmicano': 3.393190233581113e-05,
#  'ato': 6.786658871349424e-05,
#  'minha': 0.0018703889306495188,
#  'descrição': 0.00016968735209777557,
#  'produto': 0.0010191681282886492,
#  'constava': 3.393190233581113e-05,
#  'mesmo': 0.001802227233497593,
#  'bolso': 0.00020363317464294664,
#  'pelo': 0.0010872017595144636,
#  'contrário': 0.00016968735209777557,
#  'as': 0.0036807316462039654,
#  'dimensões': 3.393190233581113e-05,
#  'eram': 0.0003054873465296918,
#  'outras': 0.0004752999805117068,
#  'se': 0.0067728138311200035,
#  'eu': 0.002723349759180376,
#  'estivesse': 0.00010180405913304936,
#  'endereço': 0.0002375817812299897,
#  'entregue': 6.786658871349424e-05,
#  'teria': 0.0002375817812299897,
#  'devolvido': 3.393190233581113e-05,
#  'pestanejar': 3.393190233581113e-05,
#  'infelizmente': 0.0004752999805117068,
#  'férias': 3.393190233581113e-05,
#  'acabei': 0.0002375817812299897,
#  'perdendo': 6.786658871349424e-05,
#  'devolução': 0.00010180405913304936,
#  'observação': 3.393190233581113e-05,
#  'tenho': 0.0003394443052423508,
#  'fazer': 0.0009851554887385502,
#  'relação': 0.00020363317464294664,
#  'ao': 0.0033043570255296578,
#  'zelo': 3.393190233581113e-05,
#  'pelos': 0.0002715331718589048,
#  'produtos': 0.0002715331718589048,
#  'embalados': 6.786658871349424e-05,
#  'os': 0.004743236170272,
#  'funcionários': 3.393190233581113e-05,
#  'pesaram': 3.393190233581113e-05,
#  'mão': 6.786658871349424e-05,
#  'minhas': 0.00013574431359447646,
#  'últimas': 0.00010180405913304936,
#  'entregas': 6.786658871349424e-05,
#  'praticamente': 0.00010180405913304936,
#  'todos': 0.0006791670146719002,
#  'contêm': 3.393190233581113e-05,
#  'leves': 3.393190233581113e-05,
#  'amassados': 0.00010180405913304936,
#  'suas': 0.00044133188563156,
#  'bordas': 3.393190233581113e-05,
#  'aqui': 0.0005772209694033799,
#  'indignação': 6.786658871349424e-05,
#  'amazono': 6.786658871349424e-05,
#  'pedido': 0.0005432445223976167,
#  'veio': 0.0011212227511901776,
#  'rápido': 0.00016968735209777557,
#  'são': 0.002109042568000223,
#  'maravilhosos': 3.393190233581113e-05,
#  'box': 0.0011552465269077646,
#  'péssimas': 3.393190233581113e-05,
#  'condições': 0.00013574431359447646,
#  'parece': 0.0015637489907848222,
#  'caiu': 6.786658871349424e-05,
#  'água': 0.00013574431359447646,
#  'nele': 0.00010180405913304936,
#  'estufou': 3.393190233581113e-05,
#  'todo': 0.0010872017595144636,
#  'material': 0.0004073665747932848,
#  'mostram': 6.786658871349424e-05,
#  'imagens': 3.393190233581113e-05,
#  'pontas': 0.00013574431359447646,
#  'estão': 0.0004752999805117068,
#  'destruídas': 3.393190233581113e-05,
#  'certeza': 6.786658871349424e-05,
#  'chão': 3.393190233581113e-05,
#  'algum': 0.000373404047996882,
#  'estou': 0.0007811381163172696,
#  'frustrada': 0.00016968735209777557,
#  'primeira': 0.0004752999805117068,
#  'aquisição': 6.786658871349424e-05,
#  'amazonentrega': 3.393190233581113e-05,
#  'bem': 0.0025867590968568174,
#  'rápidamas': 3.393190233581113e-05,
#  'tanto': 0.0005432445223976167,
#  'caixaquanto': 3.393190233581113e-05,
#  'laterias': 3.393190233581113e-05,
#  'vieram': 0.0002375817812299897,
#  'pouco': 0.0010191681282886492,
#  'danificadascom': 3.393190233581113e-05,
#  'pequenas': 0.00010180405913304936,
#  'marcaso': 3.393190233581113e-05,
#  'plástico': 0.00013574431359447646,
#  'vinha': 3.393190233581113e-05,
#  'protegertambém': 3.393190233581113e-05,
#  'já': 0.00224547732397895,
#  'rasgadoincrível': 3.393190233581113e-05,
#  'e-book': 0.0004752999805117068,
#  'custa': 0.00013574431359447646,
#  'us$999': 3.393190233581113e-05,
#  'internacional': 3.393190233581113e-05,
#  'venha': 6.786658871349424e-05,
#  'custando': 3.393190233581113e-05,
#  'r$9000+': 3.393190233581113e-05,
#  'entendo': 0.00016968735209777557,
#  'conseguem': 3.393190233581113e-05,
#  'vender': 0.0002375817812299897,
#  'preços': 0.00016968735209777557,
#  'tão': 0.0009511456332303231,
#  'abusivoso': 3.393190233581113e-05,
#  'volume': 0.00016968735209777557,
#  '5': 0.00020363317464294664,
#  'esta': 0.0005432445223976167,
#  'impressão': 0.0002715331718589048,
#  'duplicada': 3.393190233581113e-05,
#  'faltandoadquiri': 3.393190233581113e-05,
#  'comemorativa': 3.393190233581113e-05,
#  'verdade': 0.000373404047996882,
#  'econômica': 6.786658871349424e-05,
#  'extremamente': 0.000373404047996882,
#  'mal': 0.0005432445223976167,
#  'feita': 0.0002715331718589048,
#  '4a': 3.393190233581113e-05,
#  '2015': 3.393190233581113e-05,
#  'papel': 0.0003394443052423508,
#  'baixa': 0.00013574431359447646,
#  'gramatura': 6.786658871349424e-05,
#  'péssima': 0.0003394443052423508,
#  'encadernação': 3.393190233581113e-05,
#  'folhas': 0.0003054873465296918,
#  'desalinhadas': 3.393190233581113e-05,
#  'há': 0.0012913694701968323,
#  'cola': 0.0002715331718589048,
#  'lombada': 3.393190233581113e-05,
#  'fonte': 0.00016968735209777557,
#  'utilizada': 3.393190233581113e-05,
#  'utlizada': 3.393190233581113e-05,
#  'total': 0.00013574431359447646,
#  'desrespeito': 0.00010180405913304936,
#  'leitor': 0.000645182215540522,
#  'pequena': 6.786658871349424e-05,
#  'torna': 0.0002715331718589048,
#  'esforço': 6.786658871349424e-05,
#  'colocar': 0.00016968735209777557,
#  'esse': 0.0026891979175366764,
#  'mercado': 3.393190233581113e-05,
#  'editora': 0.0005092708594337259,
#  'leya': 3.393190233581113e-05,
#  'comete': 0.00010180405913304936,
#  'abuso': 6.786658871349424e-05,
#  'aos': 0.000373404047996882,
#  'leitores': 0.0003394443052423508,
#  'à': 0.0010191681282886492,
#  'obra': 0.0005772209694033799,
#  'si': 0.000373404047996882,
#  'lamentável': 0.00020363317464294664,
#  'vergonhososupostamente': 3.393190233581113e-05,
#  'baixei': 3.393190233581113e-05,
#  'gratis': 3.393190233581113e-05,
#  'apos': 6.786658871349424e-05,
#  'promoçao': 3.393190233581113e-05,
#  'vocês': 0.0004073665747932848,
#  'mas': 0.005602043486734036,
#  'download': 0.00010180405913304936,
#  'realizado': 3.393190233581113e-05,
#  'houvr': 3.393190233581113e-05,
#  'algun': 3.393190233581113e-05,
#  'problemabaixei': 3.393190233581113e-05,
#  'amostra': 6.786658871349424e-05,
#  'consigo': 0.0003054873465296918,
#  'comprar': 0.0008831342743394862,
#  'versão': 0.0010872017595144636,
#  'completa': 6.786658871349424e-05,
#  'porque': 0.0010872017595144636,
#  'indisponível': 3.393190233581113e-05,
#  'entrei': 0.00013574431359447646,
#  'contato': 0.0003394443052423508,
#  'fui': 0.0004752999805117068,
#  'informada': 3.393190233581113e-05,
#  'problema': 0.0007131545978451516,
#  'página': 0.0008151340516161361,
#  'loja': 0.00016968735209777557,
#  'seria': 0.0003394443052423508,
#  'normalizado': 3.393190233581113e-05,
#  'mudança': 0.00010180405913304936,
#  'dois': 0.0007811381163172696,
#  'meses': 0.00013574431359447646,
#  'aguardando': 3.393190233581113e-05,
#  'aí': 0.0002375817812299897,
#  'será': 0.0002715331718589048,
#  'normalizadocomprei': 3.393190233581113e-05,
#  'lançamento': 0.00010180405913304936,
#  'completo': 0.00013574431359447646,
#  'segunda': 0.00020363317464294664,
#  'menos': 0.0008831342743394862,
#  'comparação': 3.393190233581113e-05,
#  'outro': 0.0006791670146719002,
#  'faltou': 6.786658871349424e-05,
#  'conteúdoachei': 3.393190233581113e-05,
#  'merchandising': 0.00010180405913304936,
#  'conteúdo': 0.0009511456332303231,
#  'prático': 6.786658871349424e-05,
#  'conteúdos': 3.393190233581113e-05,
#  'ficam': 6.786658871349424e-05,
#  'sinto': 6.786658871349424e-05,
#  'desperdicei': 3.393190233581113e-05,
#  'dinheiro': 0.0008831342743394862,
#  'gratuito': 3.393190233581113e-05,
#  'além': 0.0009171385617639692,
#  'disso': 0.0003394443052423508,
#  'muitas': 0.000645182215540522,
#  'histórias': 0.0002375817812299897,
#  'pessoais': 0.00013574431359447646,
#  'relatos': 6.786658871349424e-05,
#  'sobre': 0.0017000055680837425,
#  'milagre': 0.0002375817812299897,
#  'incrível': 0.00016968735209777557,
#  'milagreeu': 3.393190233581113e-05,
#  'também': 0.0006791670146719002,
#  'cheguei': 0.00016968735209777557,
#  'entrar': 6.786658871349424e-05,
#  'questão': 0.0002375817812299897,
#  'avaliações': 0.0003394443052423508,
#  'estas': 6.786658871349424e-05,
#  'desisti': 0.00010180405913304936,
#  'acho': 0.0002715331718589048,
#  'absurdo': 0.000373404047996882,
#  'estar': 0.00044133188563156,
#  'envolvida': 3.393190233581113e-05,
#  'pirataria': 3.393190233581113e-05,
#  'ou': 0.00200674573345583,
#  'comercializando': 3.393190233581113e-05,
#  'incorreto': 0.00013574431359447646,
#  'fraudulento': 3.393190233581113e-05,
#  'sua': 0.0009511456332303231,
#  'vez': 0.0006791670146719002,
#  'desrespeitando': 3.393190233581113e-05,
#  'consumidor': 0.00013574431359447646,
#  'absurdoprimeiramente': 3.393190233581113e-05,
#  'veiomas': 6.786658871349424e-05,
#  'me': 0.0031675770483588113,
#  'reembolsaramfavor': 3.393190233581113e-05,
#  'corrigir': 3.393190233581113e-05,
#  'formatação': 0.0003054873465296918,
#  'péssimo': 0.0003054873465296918,
#  'possível': 0.0002375817812299897,
#  'forma': 0.0011552465269077646,
#  'portanto': 0.00010180405913304936,
#  'amzon': 3.393190233581113e-05,
#  'corrija': 6.786658871349424e-05,
#  'brilhante': 3.393190233581113e-05,
#  'conforme': 6.786658871349424e-05,
#  'outros': 0.0007811381163172696,
#  'compradores': 6.786658871349424e-05,
#  'abaixo': 0.00016968735209777557,
#  'optei': 3.393190233581113e-05,
#  'amamossp': 3.393190233581113e-05,
#  'sairia': 3.393190233581113e-05,
#  'qual': 0.0004073665747932848,
#  'surpresa': 0.0003054873465296918,
#  'cobrando': 6.786658871349424e-05,
#  'equivocadamente': 6.786658871349424e-05,
#  'digital': 0.0004752999805117068,
#  'r$': 0.0002375817812299897,
#  '2100a': 3.393190233581113e-05,
#  'literatura': 6.786658871349424e-05,
#  'contestar': 3.393190233581113e-05,
#  'épico': 3.393190233581113e-05,
#  'propaganda': 0.00020363317464294664,
#  'enganosa': 3.393190233581113e-05,
#  'cita': 0.00020363317464294664,
#  'ilustrada': 3.393190233581113e-05,
#  'pequeno': 0.00010180405913304936,
#  'encarte': 3.393190233581113e-05,
#  'algumas': 0.0005772209694033799,
#  'ilustrações': 0.0002375817812299897,
#  'completamente': 0.0004752999805117068,
#  'fora': 0.0003394443052423508,
#  'contexto': 6.786658871349424e-05,
#  'cantos': 3.393190233581113e-05,
#  'truncada': 3.393190233581113e-05,
#  'você': 0.0015637489907848222,
#  'quer': 0.0005432445223976167,
#  'acompanhar': 3.393190233581113e-05,
#  'texto': 0.0010872017595144636,
#  'junto': 0.00013574431359447646,
#  'ilustração': 3.393190233581113e-05,
#  'neste': 0.0002375817812299897,
#  'sentido': 0.0003394443052423508,
#  'frustante': 3.393190233581113e-05,
#  'adquirir': 0.00020363317464294664,
#  'divina': 6.786658871349424e-05,
#  'comédia': 6.786658871349424e-05,
#  'todas': 0.0003054873465296918,
#  'gustave': 0.00010180405913304936,
#  'doreo': 3.393190233581113e-05,
#  'rasgado': 0.00016968735209777557,
#  'perfeitos': 6.786658871349424e-05,
#  'estado': 0.0003054873465296918,
#  'lindos': 3.393190233581113e-05,
#  'pena': 0.00044133188563156,
#  'isso': 0.00224547732397895,
#  'aconteça': 3.393190233581113e-05,
#  'aindao': 3.393190233581113e-05,
#  'bom': 0.0009511456332303231,
#  'configuração': 3.393190233581113e-05,
#  'formato': 0.0003394443052423508,
#  'kindle': 0.0012913694701968323,
#  'ficou': 0.00016968735209777557,
#  'impacta': 3.393190233581113e-05,
#  'recomendo': 0.0007471449650602748,
#  'kindleprimeiramente': 3.393190233581113e-05,
#  'reembolsaramcomprei': 3.393190233581113e-05,
#  'ele': 0.0019726523566914434,
#  'nao': 0.0005772209694033799,
#  'vai': 0.000849132770956875,
#  'biblioteca': 0.00013574431359447646,
#  'solucao': 3.393190233581113e-05,
#  'agora': 0.0004073665747932848,
#  'tento': 3.393190233581113e-05,
#  'novamente': 0.0003054873465296918,
#  'fala': 0.0006791670146719002,
#  'ja': 0.00010180405913304936,
#  'compreio': 3.393190233581113e-05,
#  'queria': 0.0004752999805117068,
#  'reler': 0.00016968735209777557,
#  'cobrado': 0.00016968735209777557,
#  'brasil': 0.0006112002004510151,
#  'ebook': 0.0004752999805117068,
#  'patético': 6.786658871349424e-05,
#  'abusivo': 0.0002375817812299897,
#  'hoje': 0.0003394443052423508,
#  '$1398': 3.393190233581113e-05,
#  'quase': 0.000645182215540522,
#  '1/4': 3.393190233581113e-05,
#  'desse': 0.0007131545978451516,
#  'for': 0.00010180405913304936,
#  'convertido': 3.393190233581113e-05,
#  'real': 0.00013574431359447646,
#  'americana': 0.00020363317464294664,
#  'nada': 0.002109042568000223,
#  'justifica': 0.00016968735209777557,
#  'exceto': 3.393190233581113e-05,
#  'querer': 0.00013574431359447646,
#  'super': 0.00016968735209777557,
#  'faturar': 3.393190233581113e-05,
#  'tradução': 0.0007811381163172696,
#  'existe': 0.0003054873465296918,
#  'milênios': 3.393190233581113e-05,
#  'vergonha': 6.786658871349424e-05,
#  'alheia': 3.393190233581113e-05,
#  'decepção': 0.00013574431359447646,
#  'pela': 0.0014615857902502854,
#  'sintocomprei': 3.393190233581113e-05,
#  'baixou': 6.786658871349424e-05,
#  'saber': 0.000373404047996882,
#  'baixar': 0.00013574431359447646,
#  'quero': 0.0002375817812299897,
#  'lê': 0.00016968735209777557,
#  '-lo': 3.393190233581113e-05,
#  'grata': 3.393190233581113e-05,
#  'atençãoo': 3.393190233581113e-05,
#  'barato': 6.786658871349424e-05,
#  'sai': 3.393190233581113e-05,
#  'realmente': 0.0008151340516161361,
#  'caro': 0.0002715331718589048,
#  'enviam': 3.393190233581113e-05,
#  '192': 3.393190233581113e-05,
#  '225': 3.393190233581113e-05,
#  'inconformadanão': 3.393190233581113e-05,
#  'recebi': 0.0003054873465296918,
#  'tenham': 6.786658871349424e-05,
#  'enviado': 3.393190233581113e-05,
#  'errado': 0.0002375817812299897,
#  'fosse': 0.0004073665747932848,
#  'encaminhado': 3.393190233581113e-05,
#  'aguardo': 6.786658871349424e-05,
#  'breve': 3.393190233581113e-05,
#  'retornonão': 3.393190233581113e-05,
#  'confuso': 0.00016968735209777557,
#  'ninguém': 0.0005092708594337259,
#  'ajuda': 0.000373404047996882,
#  'complicado': 0.00010180405913304936,
#  'conseguir': 0.00010180405913304936,
#  'estornocomo': 3.393190233581113e-05,
#  'preço': 0.0011892730866672238,
#  'comprarmos': 3.393190233581113e-05,
#  'eles': 0.0003394443052423508,
#  'gastam': 3.393190233581113e-05,
#  'custar': 6.786658871349424e-05,
#  'tivesse': 0.00010180405913304936,
#  'iriam': 3.393190233581113e-05,
#  'incrivel': 3.393190233581113e-05,
#  'vale': 0.0008151340516161361,
#  'preçonão': 3.393190233581113e-05,
#  'havia': 0.00013574431359447646,
#  'informação': 0.00020363317464294664,
#  'fiquei': 0.0005772209694033799,
#  'mto': 3.393190233581113e-05,
#  'insatisfeita': 3.393190233581113e-05,
#  'tomar': 3.393190233581113e-05,
#  'conhecimento': 0.0003054873465296918,
#  'quem': 0.0013254071661237775,
#  'foram': 0.0004752999805117068,
#  'doadosacabo': 3.393190233581113e-05,
#  'ver': 0.0008831342743394862,
#  'trilogia': 0.000373404047996882,
#  'impressa': 0.0003054873465296918,
#  '5490': 6.786658871349424e-05,
#  'ridícula': 0.00010180405913304936,
#  'pensava': 6.786658871349424e-05,
#  'seriamente': 6.786658871349424e-05,
#  'vou': 0.0006112002004510151,
#  'ficar': 0.0003054873465296918,
#  'inviáveldiante': 3.393190233581113e-05,
#  'tantos': 0.0003054873465296918,
#  'comentários': 0.0003054873465296918,
#  'espinafrando': 3.393190233581113e-05,
#  'má': 6.786658871349424e-05,
#  'falta': 0.0004073665747932848,
#  'respeito': 0.000373404047996882,
#  'obras': 0.0002715331718589048,
#  'vendidas': 3.393190233581113e-05,
#  'através': 0.0002375817812299897,
#  'problemas': 0.0003394443052423508,
#  'tomei': 3.393190233581113e-05,
#  'decisão': 3.393190233581113e-05,
#  'li': 0.0007131545978451516,
#  'recente': 3.393190233581113e-05,
#  'maio': 6.786658871349424e-05,
#  '2014': 3.393190233581113e-05,
#  'relata': 3.393190233581113e-05,
#  'permanece': 3.393190233581113e-05,
#  'lamentávelnão': 3.393190233581113e-05,
#  'comprem': 0.00013574431359447646,
#  'cobra': 3.393190233581113e-05,
#  'dobro': 3.393190233581113e-05,
#  'nos': 0.000849132770956875,
#  'eua': 3.393190233581113e-05,
#  'estamos': 6.786658871349424e-05,
#  'financiando': 3.393190233581113e-05,
#  'criseo': 3.393190233581113e-05,
#  'celular': 3.393190233581113e-05,
#  'exibido': 3.393190233581113e-05,
#  'duas': 0.00044133188563156,
#  'colunas': 3.393190233581113e-05,
#  'dificultando': 3.393190233581113e-05,
#  'procurando': 6.786658871349424e-05,
#  'obtivena': 3.393190233581113e-05,
#  'época': 0.00020363317464294664,
#  'estourou': 3.393190233581113e-05,
#  'paguei': 0.0002375817812299897,
#  '105': 3.393190233581113e-05,
#  'especial': 0.00013574431359447646,
#  'motivo': 6.786658871349424e-05,
#  'pagaria': 3.393190233581113e-05,
#  '99': 3.393190233581113e-05,
#  'cor': 6.786658871349424e-05,
#  'desenho': 6.786658871349424e-05,
#  'comprecomprei': 3.393190233581113e-05,
#  'arrependi': 0.00010180405913304936,
#  'profundamente': 3.393190233581113e-05,
#  'claramente': 0.0002715331718589048,
#  'passaram': 3.393190233581113e-05,
#  'tempo': 0.0010191681282886492,
#  'polindo': 3.393190233581113e-05,
#  'ela': 0.0005432445223976167,
#  'existem': 0.00010180405913304936,
#  'diversos': 0.00013574431359447646,
#  'erros': 0.000373404047996882,
#  'simples': 0.0003054873465296918,
#  'revisão': 0.00013574431359447646,
#  'capturadonão': 3.393190233581113e-05,
#  'estornomeu': 3.393190233581113e-05,
#  'lateral': 3.393190233581113e-05,
#  'descolando': 6.786658871349424e-05,
#  'apresentando': 6.786658871349424e-05,
#  'bolhas': 0.00010180405913304936,
#  'ar': 3.393190233581113e-05,
#  'conta': 0.000373404047996882,
#  'descolamento': 3.393190233581113e-05,
#  'lindomuito': 3.393190233581113e-05,
#  'grosseiros': 3.393190233581113e-05,
#  'adaptado': 3.393190233581113e-05,
#  'corretamento': 3.393190233581113e-05,
#  'dá': 0.0004073665747932848,
#  'escanearam': 3.393190233581113e-05,
#  'jogar': 0.00020363317464294664,
#  'pdf': 6.786658871349424e-05,
#  'coxas': 3.393190233581113e-05,
#  'horrível': 0.00016968735209777557,
#  'notas': 0.00010180405913304936,
#  'rodapé': 6.786658871349424e-05,
#  'aparecem': 0.00010180405913304936,
#  'meio': 0.0006112002004510151,
#  'especialistas': 3.393190233581113e-05,
#  'dostoiévski': 3.393190233581113e-05,
#  'cultura': 0.00010180405913304936,
#  'russa': 3.393190233581113e-05,
#  'castigaram': 3.393190233581113e-05,
#  'trecho': 3.393190233581113e-05,
#  'grande': 0.0005432445223976167,
#  'inquisidor': 6.786658871349424e-05,
#  'colocadasminha': 3.393190233581113e-05,
#  'experiência': 0.00020363317464294664,
#  'compras': 6.786658871349424e-05,
#  'comprei': 0.0008151340516161361,
#  'item': 6.786658871349424e-05,
#  'presentear': 6.786658871349424e-05,
#  'atentei': 3.393190233581113e-05,
#  'data': 0.00020363317464294664,
#  'limite': 0.00010180405913304936,
#  'chegada': 3.393190233581113e-05,
#  'conseguisse': 3.393190233581113e-05,
#  'entregá-lo': 3.393190233581113e-05,
#  'correta': 3.393190233581113e-05,
#  'chegaram': 0.00020363317464294664,
#  'pior': 0.0005772209694033799,
#  'transportadora': 0.00016968735209777557,
#  'atualizou': 3.393190233581113e-05,
#  'status': 0.00010180405913304936,
#  'dias': 0.000373404047996882,
#  'antes': 0.000645182215540522,
#  'provavelmente': 0.00013574431359447646,
#  'perder': 6.786658871349424e-05,
#  'pontuação': 6.786658871349424e-05,
#  'fluxo': 3.393190233581113e-05,
#  'aumentam': 3.393190233581113e-05,
#  'considero': 6.786658871349424e-05,
#  'omitir': 3.393190233581113e-05,
#  'entrega': 0.0004073665747932848,
#  'positivos': 3.393190233581113e-05,
#  'ouvi': 0.00010180405913304936,
#  'mim': 0.0002715331718589048,
#  'concretizaram': 3.393190233581113e-05,
#  'voltarei': 3.393190233581113e-05,
#  'comprarchegou': 3.393190233581113e-05,
#  'incrivelmente': 6.786658871349424e-05,
#  'embalagem': 0.00010180405913304936,
#  'ainda': 0.0011552465269077646,
#  'percy': 6.786658871349424e-05,
#  'jackson': 6.786658871349424e-05,
#  'hp': 6.786658871349424e-05,
#  'i': 3.393190233581113e-05,
#  'triste': 0.0003054873465296918,
#  'issomuita': 3.393190233581113e-05,
#  'gente': 0.0002375817812299897,
#  'comprou': 6.786658871349424e-05,
#  'reclamou': 6.786658871349424e-05,
#  'chegou': 0.0007471449650602748,
#  'defeito': 0.00016968735209777557,
#  'achei': 0.0014275369581558497,
#  'viria': 3.393190233581113e-05,
#  'perfeito': 0.00016968735209777557,
#  'provável': 0.00010180405913304936,
#  'somente': 0.00016968735209777557,
#  'estragados': 3.393190233581113e-05,
#  'nunca': 0.0005772209694033799,
#  'compro': 0.00010180405913304936,
#  'faltando': 0.00010180405913304936,
#  'capítulosgostaria': 3.393190233581113e-05,
#  'trocassem': 3.393190233581113e-05,
#  'ótimo': 0.0003394443052423508,
#  'posso': 0.0003054873465296918,
#  'terminar': 0.00044133188563156,
#  'capítuloseu': 3.393190233581113e-05,
#  'ia': 0.00016968735209777557,
#  'fato': 0.00020363317464294664,
#  'maioria': 0.0002375817812299897,
#  'comentarios': 3.393190233581113e-05,
#  'serem': 0.0002375817812299897,
#  'negativos': 3.393190233581113e-05,
#  'la': 6.786658871349424e-05,
#  'aventurar': 3.393190233581113e-05,
#  'casa': 0.0003394443052423508,
#  'recém': 3.393190233581113e-05,
#  'rasgadas': 0.00020363317464294664,
#  'sí': 3.393190233581113e-05,
#  'sujo': 3.393190233581113e-05,
#  'arranhado': 3.393190233581113e-05,
#  'principalmente': 0.0003054873465296918,
#  'lombadas': 3.393190233581113e-05,
#  'tudo': 0.0013254071661237775,
#  'eai': 3.393190233581113e-05,
#  'vc': 0.0002715331718589048,
#  'ta': 3.393190233581113e-05,
#  'fazendo': 0.00013574431359447646,
#  'jogo': 6.786658871349424e-05,
#  'comigo': 0.00010180405913304936,
#  '1': 0.000373404047996882,
#  '4': 0.00016968735209777557,
#  'estao': 6.786658871349424e-05,
#  'descoladas': 3.393190233581113e-05,
#  'pedi': 6.786658871349424e-05,
#  'reembolsoe': 3.393190233581113e-05,
#  'aconselho': 6.786658871349424e-05,
#  'duvidas': 6.786658871349424e-05,
#  'comprarem': 3.393190233581113e-05,
#  'olhem': 3.393190233581113e-05,
#  'fotos': 0.00013574431359447646,
#  'tirem': 3.393190233581113e-05,
#  'próprias': 6.786658871349424e-05,
#  'conclusõesao': 3.393190233581113e-05,
#  'então': 0.0003394443052423508,
#  'encontrado': 3.393190233581113e-05,
#  'nenhum': 0.0005772209694033799,
#  'harry': 0.0002715331718589048,
#  'potter': 0.0002375817812299897,
#  'ordem': 0.00010180405913304936,
#  'fênix': 6.786658871349424e-05,
#  'encontrei': 6.786658871349424e-05,
#  'grave': 3.393190233581113e-05,
#  'chega': 0.00020363317464294664,
#  'impedir': 3.393190233581113e-05,
#  'continuar': 0.0002715331718589048,
#  'garantindo': 3.393190233581113e-05,
#  'boa': 0.000645182215540522,
#  'impedindo-o': 3.393190233581113e-05,
#  'história': 0.0020749408391102196,
#  'capítulo': 0.0002375817812299897,
#  'trinta': 3.393190233581113e-05,
#  'noms': 3.393190233581113e-05,
#  'inicia': 0.00010180405913304936,
#  'segue': 0.00016968735209777557,
#  'normalmente': 3.393190233581113e-05,
#  'chegar': 0.0004073665747932848,
#  '576': 6.786658871349424e-05,
#  'onde': 0.0004073665747932848,
#  'deveria': 0.0005432445223976167,
#  'haver': 6.786658871349424e-05,
#  'próxima': 0.00016968735209777557,
#  '577': 6.786658871349424e-05,
#  'seu': 0.0015637489907848222,
#  'lugar': 0.00016968735209777557,
#  '545': 3.393190233581113e-05,
#  'assim': 0.0007471449650602748,
#  'nova': 0.00013574431359447646,
#  '609': 3.393190233581113e-05,
#  'pulando': 0.00016968735209777557,
#  '2': 0.0003394443052423508,
#  'capítulos': 0.0004073665747932848,
#  'resistente': 3.393190233581113e-05,
#  'bonito': 3.393190233581113e-05,
#  'qualidade': 0.0007471449650602748,
#  'aquele': 0.00013574431359447646,
#  'cabem': 3.393190233581113e-05,
#  'possuem': 6.786658871349424e-05,
#  'excelente': 0.00020363317464294664,
#  'capas': 0.00016968735209777557,
#  'bonitas': 6.786658871349424e-05,
#  'menor': 0.00010180405913304936,
#  'atrapalhe': 3.393190233581113e-05,
#  'transporte': 0.00010180405913304936,
#  'ótimofiz': 3.393190233581113e-05,
#  'errada': 0.00010180405913304936,
#  'comprando': 0.00020363317464294664,
#  'cancelar': 0.00010180405913304936,
#  'segredo': 6.786658871349424e-05,
#  'mente': 0.00010180405913304936,
#  'milionária': 3.393190233581113e-05,
#  'obrigada': 0.00013574431359447646,
#  'karlano': 3.393190233581113e-05,
#  '24-05-2018': 3.393190233581113e-05,
#  'fiz': 0.00020363317464294664,
#  'ai': 0.00016968735209777557,
#  'porem': 0.00010180405913304936,
#  'justo': 3.393190233581113e-05,
#  'semana': 0.00013574431359447646,
#  'diante': 0.00016968735209777557,
#  'dessa': 0.0005092708594337259,
#  'efetuei': 3.393190233581113e-05,
#  'tremenda': 3.393190233581113e-05,
#  'greve': 0.00010180405913304936,
#  'geral': 0.0002375817812299897,
#  'atendente': 3.393190233581113e-05,
#  'recomendou': 6.786658871349424e-05,
#  'iria': 6.786658871349424e-05,
#  'separação': 0.00016968735209777557,
#  'estoque': 3.393190233581113e-05,
#  'politica': 3.393190233581113e-05,
#  'interna': 3.393190233581113e-05,
#  'cancelei': 3.393190233581113e-05,
#  'seguida': 6.786658871349424e-05,
#  'fez': 0.0002715331718589048,
#  'reembolso': 0.00020363317464294664,
#  'dali': 3.393190233581113e-05,
#  'começou': 0.00010180405913304936,
#  'dor': 3.393190233581113e-05,
#  'cabeça': 0.0002715331718589048,
#  'fazem': 0.00013574431359447646,
#  'semanas': 0.00016968735209777557,
#  'cancelado': 6.786658871349424e-05,
#  'cair': 6.786658871349424e-05,
#  'debito': 6.786658871349424e-05,
#  'vista': 0.00013574431359447646,
#  'significa': 6.786658871349424e-05,
#  'acontecer': 0.00010180405913304936,
#  'burocracia': 0.00010180405913304936,
#  'obsverifiquei': 3.393190233581113e-05,
#  'banco': 3.393190233581113e-05,
#  'consta': 3.393190233581113e-05,
#  'credito': 3.393190233581113e-05,
#  'pendente': 3.393190233581113e-05,
#  'contaA': 3.393190233581113e-05,
#  'caixa': 0.0006112002004510151,
#  'rasgada': 0.0002375817812299897,
#  'parecem': 0.00020363317464294664,
#  'usadosa': 3.393190233581113e-05,
#  'queira': 6.786658871349424e-05,
#  'pocket': 0.00020363317464294664,
#  'compre': 0.00020363317464294664,
#  'diz': 0.0004752999805117068,
#  'irá': 0.00010180405913304936,
#  'reais': 0.00016968735209777557,
#  'seja': 0.0007811381163172696,
#  'desonestos': 3.393190233581113e-05,
#  'prejudicaram': 3.393190233581113e-05,
#  'submarino': 6.786658871349424e-05,
#  'vendedores': 3.393190233581113e-05,
#  'honestos': 3.393190233581113e-05,
#  'nãocomprei': 3.393190233581113e-05,
#  'depois': 0.0007471449650602748,
#  'confundi': 6.786658871349424e-05,
#  'mesma': 0.0005772209694033799,
#  'faturou': 3.393190233581113e-05,
#  'pedidos': 3.393190233581113e-05,
#  'feitos': 3.393190233581113e-05,
#  'permite': 6.786658871349424e-05,
#  'duplicadas': 3.393190233581113e-05,
#  'isto': 0.00016968735209777557,
#  'tratando': 3.393190233581113e-05,
#  'abismada': 6.786658871349424e-05,
#  'negativas': 6.786658871349424e-05,
#  'ano': 0.00016968735209777557,
#  'dele': 0.000373404047996882,
#  'ter': 0.0017681505609844373,
#  'baixado': 6.786658871349424e-05,
#  'adquiri': 0.00010180405913304936,
#  'recentemente': 0.00010180405913304936,
#  'feliz': 0.00013574431359447646,
#  'entusiasmada': 3.393190233581113e-05,
#  'senhor': 0.00016968735209777557,
#  'anéis': 0.00013574431359447646,
#  'deparei': 0.00010180405913304936,
#  'hora': 0.0002715331718589048,
#  'apenas': 0.0009511456332303231,
#  'lógica': 6.786658871349424e-05,
#  'estratosférico': 3.393190233581113e-05,
#  'pagando': 3.393190233581113e-05,
#  'francamentemeu': 3.393190233581113e-05,
#  'alguma': 0.0007131545978451516,
#  'alguns': 0.0002715331718589048,
#  'orelha': 0.00010180405913304936,
#  'surradadecepção': 3.393190233581113e-05,
#  'to': 3.393190233581113e-05,
#  'ansioso': 3.393190233581113e-05,
#  'abri': 6.786658871349424e-05,
#  'vi': 0.000373404047996882,
#  'das': 0.0015978089590467455,
#  'transparentes': 6.786658871349424e-05,
#  'vê': 0.00020363317464294664,
#  'letras': 0.00016968735209777557,
#  'verso': 6.786658871349424e-05,
#  'capa': 0.000645182215540522,
#  'linda': 3.393190233581113e-05,
#  'tirar': 0.00013574431359447646,
#  'foto': 0.00010180405913304936,
#  'postar': 3.393190233581113e-05,
#  'rede': 3.393190233581113e-05,
#  'mancha': 3.393190233581113e-05,
#  'enorme': 0.00016968735209777557,
#  'terceiro': 0.00020363317464294664,
#  "--'": 3.393190233581113e-05,
#  'serviurealmente': 3.393190233581113e-05,
#  'sucesso': 0.0006112002004510151,
#  'desses': 0.00016968735209777557,
#  'vendido': 0.00010180405913304936,
#  'numa': 0.000373404047996882,
#  'teve': 0.00016968735209777557,
#  'custo': 0.00013574431359447646,
#  'mínimo': 0.00020363317464294664,
#  'produção': 6.786658871349424e-05,
#  '0': 6.786658871349424e-05,
#  'venda': 0.00020363317464294664,
#  'num': 0.000373404047996882,
#  '2x': 3.393190233581113e-05,
#  'maior': 0.000373404047996882,
#  'físico': 6.786658871349424e-05,
#  'custos': 3.393190233581113e-05,
#  'distribuição': 3.393190233581113e-05,
#  'infinitamente': 3.393190233581113e-05,
#  'maiores': 6.786658871349424e-05,
#  'simplesmente': 0.0002375817812299897,
#  'perdeu': 0.0002375817812299897,
#  'tinha': 0.00044133188563156,
#  'empresajá': 3.393190233581113e-05,
#  'lido': 0.0002375817812299897,
#  'anteriores': 0.00010180405913304936,
#  'diversas': 0.00010180405913304936,
#  'reclamações': 3.393190233581113e-05,
#  'antecipadamente': 3.393190233581113e-05,
#  'tensa': 3.393190233581113e-05,
#  'premiada': 3.393190233581113e-05,
#  'danificado': 0.0002715331718589048,
#  'espera-se': 3.393190233581113e-05,
#  'receber': 0.00010180405913304936,
#  'acontece': 0.000373404047996882,
#  'jogasse': 3.393190233581113e-05,
#  'balde': 3.393190233581113e-05,
#  'fria': 6.786658871349424e-05,
#  'dar': 0.0003394443052423508,
#  'indelicado': 3.393190233581113e-05,
#  'demais': 0.0002715331718589048,
#  'normais': 3.393190233581113e-05,
#  'defeitospéssima': 3.393190233581113e-05,
#  'partes': 0.00020363317464294664,
#  'comprado': 0.00010180405913304936,
#  'kindlefrases': 3.393190233581113e-05,
#  'e/ou': 3.393190233581113e-05,
#  'faltantes': 3.393190233581113e-05,
#  'talvez': 0.0004752999805117068,
#  'tenha': 0.00044133188563156,
#  'acontecido': 0.00010180405913304936,
#  'online': 6.786658871349424e-05,
#  'simcomprei': 3.393190233581113e-05,
#  'ambos': 0.00010180405913304936,
#  'prazos': 3.393190233581113e-05,
#  'estipulados': 3.393190233581113e-05,
#  'demorei': 6.786658871349424e-05,
#  'abrir': 0.00016968735209777557,
#  'começar': 0.00016968735209777557,
#  'segundo': 0.0002715331718589048,
#  'reparo': 6.786658871349424e-05,
#  '3': 0.00013574431359447646,
#  'fico': 0.00010180405913304936,
#  'decepcionado': 0.00016968735209777557,
#  'tipo': 0.0005432445223976167,
#  'situação': 0.00010180405913304936,
#  'aja': 3.393190233581113e-05,
#  'ação': 0.00010180405913304936,
#  'quanto': 0.00044133188563156,
#  'serei': 3.393190233581113e-05,
#  'obrigado': 0.00016968735209777557,
#  'conferir': 6.786658871349424e-05,
#  'seus': 0.0006112002004510151,
#  'respectivos': 3.393190233581113e-05,
#  'gosto': 0.0003394443052423508,
#  'tomem': 3.393190233581113e-05,
#  'posição': 6.786658871349424e-05,
#  'issocomo': 3.393190233581113e-05,
#  'aproveitar': 6.786658871349424e-05,
#  'longo': 0.00016968735209777557,
#  'anos': 0.0006791670146719002,
#  'cobrar': 3.393190233581113e-05,
#  'nesse': 0.000373404047996882,
#  'país': 0.00020363317464294664,
#  'corrupto': 3.393190233581113e-05,
#  ...}

# %%
df_test
# Out:
#                                               Mensagem    Target
# 0    a narrativa é muito lenta e você fica ansioso ...  conteúdo
# 1    simadorei o livro vou continuar a comprar o re...  conteúdo
# 2    desculpem mas achei deprimente e não me ensino...  conteúdo
# 3    preciso saber se essa compra é do livro físico...   entrega
# 4    embora tenha gostado do livro não faz sentido ...  conteúdo
# ..                                                 ...       ...
# 245  livro ruim comparado com seu antecessor a auto...  conteúdo
# 246  coaching virou um grande modismo assim como cr...  conteúdo
# 247  nao gostei nem da formatacao nem do conteudo u...  conteúdo
# 248  para quem tem um mínimo de conhecimento em fin...  conteúdo
# 249  primeiramente é super previsível e o romance n...  conteúdo
#
# [250 rows x 2 columns]

# %%
prob_entrega = len(serie_entrega)/len(serie_geral)
prob_conteudo = len(serie_conteudo)/len(serie_geral)

# %%
prob_conteudo

tabela_conteudo
# Out:
# de             0.037148
# que            0.033200
# e              0.031405
# o              0.030807
# a              0.028235
#                  ...
# 21             0.000060
# repassei       0.000060
# suposta        0.000060
# devolvi        0.000060
# psicológica    0.000060
# Length: 4222, dtype: float64

# %%
prob_entrega
# Out:
# 0.3142153846153846

# %%
lista_frases_teste = []
for frase in df_test['Mensagem']:
    lista_frases_teste.append(frase.split())

frase_de_teste = lista_frases_teste[0]

P_frase_tal_C = 1


P_frase_tal_C *= tabela_conteudo[frase_de_teste]
        

P_frase_tal_C
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12196\1062083956.py in <module>
#       8
#       9
# ---> 10 P_frase_tal_C *= tabela_conteudo[frase_de_teste]
#      11
#      12
#
# c:\Users\Felipe\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     982             return self._get_values(key)
#     983
# --> 984         return self._get_with(key)
#     985
#     986     def _get_with(self, key):
#
# c:\Users\Felipe\anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#    1022
#    1023         # handle the dup indexing case GH#4246
# -> 1024         return self.loc[key]
#    1025
#    1026     def _get_values_tuple(self, key):
#
# c:\Users\Felipe\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# c:\Users\Felipe\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1192                     raise ValueError("Cannot index with multidimensional key")
#    1193
# -> 1194                 return self._getitem_iterable(key, axis=axis)
#    1195
#    1196             # nested tuple slicing
#
# c:\Users\Felipe\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1130
#    1131         # A collection of keys
# -> 1132         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1133         return self.obj._reindex_with_indexers(
#    1134             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# c:\Users\Felipe\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1328         axis_name = self.obj._get_axis_name(axis)
#    1329
# -> 1330         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1331
#    1332         return keyarr, indexer
#
# c:\Users\Felipe\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# c:\Users\Felipe\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5859             raise KeyError(f"{not_found} not in index")
#    5860
#    5861     @overload
#
# KeyError: "['ansioso'] not in index"

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# ___
# ### Qualidade do Classificador a partir de novas separações dos tweets entre Treinamento e Teste
#
# Caso for fazer esse item do Projeto

# %% [markdown]
# ___
# ## Aperfeiçoamento:
#
# Trabalhos que conseguirem pelo menos conceito B vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * IMPLEMENTOU outras limpezas e transformações que não afetem a qualidade da informação contida nos tweets. Ex: stemming, lemmatization, stopwords
# * CONSIDEROU mais de duas categorias na variável Target e INCREMENTOU a quantidade de notícias, mantendo pelo menos 250 notícias por categoria (OBRIGATÓRIO PARA TRIOS, sem contar como item avançado)
# * Para Target com duas categorias: CRIOU pelo menos quatro categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante
# * EXPLICOU porquê não pode usar o próprio classificador para gerar mais amostras de treinamento
# * PROPÔS diferentes cenários para Naïve Bayes fora do contexto do projeto (pelo menos dois cenários, exceto aqueles já apresentados em sala pelos professores: por exemplo, filtro de spam)
# * SUGERIU e EXPLICOU melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)
# * FEZ o item Qualidade do Classificador a partir de novas separações das Notícias entre Treinamento e Teste descrito no enunciado do projeto (OBRIGATÓRIO para conceitos A ou A+)

# %% [markdown]
# ___
# ## Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
