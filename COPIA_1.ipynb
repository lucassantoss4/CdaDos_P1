# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Caio Monteiro Marquez Barbosa
# Felipe Bakowski Nantes de Souza
# Lucas Santos Teixeira

# %% [markdown]
# Atenção: Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# Carregando algumas bibliotecas:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# c:\Users\Felipe\Desktop\CdaDos_P1

# %% [markdown]
# Carregando a base de dados com os tweets classificados manualmente:

# %%
train = pd.read_excel('dados_treino.xlsx')
train.head(5)
# Out:
#                                             Mensagem  Unnamed: 1  Unnamed: 2  \
# 0  Um dos livros faltam mais de 40 páginas. Ex.: ...         NaN         NaN
# 1  O livro é incompleto. Acaba em 11/04/44, sendo...         NaN         NaN
# 2  Ainda não terminei, estou nos 40%, devo ler em...         NaN         NaN
# 3  Pedi o livro baseado na promoção q era de graç...         NaN         NaN
# 4  Prezados, Acredito que houve um erro, pois des...         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  ...  Unnamed: 87  Unnamed: 88  Unnamed: 89  Unnamed: 90  \
# 0         NaN  ...          NaN          NaN          NaN          NaN
# 1         NaN  ...          NaN          NaN          NaN          NaN
# 2         NaN  ...          NaN          NaN          NaN          NaN
# 3         NaN  ...          NaN          NaN          NaN          NaN
# 4         NaN  ...          NaN          NaN          NaN          NaN
#
#    Unnamed: 91  Unnamed: 92  Unnamed: 93  Unnamed: 94  Unnamed: 95    Target
# 0          NaN          NaN          NaN          NaN          NaN   entrega
# 1          NaN          NaN          NaN          NaN          NaN   entrega
# 2          NaN          NaN          NaN          NaN          NaN  conteúdo
# 3          NaN          NaN          NaN          NaN          NaN   entrega
# 4          NaN          NaN          NaN          NaN          NaN   entrega
#
# [5 rows x 97 columns]

# %%
test = pd.read_excel('dados_teste.xlsx')
test.head(5)
# Out:
#                                             Mensagem  Unnamed: 1  Unnamed: 2  \
# 0  a narrativa é muito lenta e você fica ansioso ...         NaN         NaN
# 1  Sim.adorei o livro Vou continuar a comprar o r...         NaN         NaN
# 2  Desculpem, mas achei deprimente e não me ensin...         NaN         NaN
# 3  Preciso saber se essa compra é do livro físico...         NaN         NaN
# 4  Embora tenha gostado do livro "Não Faz Sentido...         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  ...  Unnamed: 33  Unnamed: 34  Unnamed: 35 Unnamed: 36  \
# 0         NaN  ...          NaN          NaN          NaN         NaN
# 1         NaN  ...          NaN          NaN          NaN         NaN
# 2         NaN  ...          NaN          NaN          NaN         NaN
# 3         NaN  ...          NaN          NaN          NaN         NaN
# 4         NaN  ...          NaN          NaN          NaN         NaN
#
#    Unnamed: 37  Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41    Target
# 0          NaN          NaN          NaN          NaN          NaN  conteúdo
# 1          NaN          NaN          NaN          NaN          NaN  conteúdo
# 2          NaN          NaN          NaN          NaN          NaN  conteúdo
# 3          NaN          NaN          NaN          NaN          NaN   entrega
# 4          NaN          NaN          NaN          NaN          NaN  conteúdo
#
# [5 rows x 43 columns]

# %% [markdown]
# ___
# ## Classificador automático

# %% [markdown]
# Faça aqui uma descrição do seu assunto e o que considerou como relevante ou não relevante na classificação dos tweets (Target).
#
# ESCREVA AQUI...

# %% [markdown]
# ___
# ### Montando um Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %%
df_train = train['Mensagem'].to_frame()
df_train['Target'] = train['Target']

df_test = test['Mensagem'].to_frame()
df_test['Target'] = test['Target']

# %%
caracteres = [':',',','.','(',')', '?', '!', '"']
i = 0
for msg in df_train.Mensagem:
    for caractere in caracteres:
        if caractere in msg:
            msg = msg.replace(caractere, '')
            msg = msg.lower()
    df_train.loc[i, 'Mensagem'] = msg 
    i += 1
    
    
j = 0
for msg in df_test.Mensagem:
    for caractere in caracteres:
        if caractere in msg:
            msg = msg.replace(caractere, '')
            msg = msg.lower()
    df_test.loc[j, 'Mensagem'] = msg 
    j += 1

# %%
df_train.head(5)
# Out:
#                                             Mensagem    Target
# 0  um dos livros faltam mais de 40 páginas ex pul...   entrega
# 1  o livro é incompleto acaba em 11/04/44 sendo q...   entrega
# 2  ainda não terminei estou nos 40% devo ler em m...  conteúdo
# 3  pedi o livro baseado na promoção q era de graç...   entrega
# 4  prezados acredito que houve um erro pois desco...   entrega

# %%
df_test.head(5)
# Out:
#                                             Mensagem    Target
# 0  a narrativa é muito lenta e você fica ansioso ...  conteúdo
# 1  simadorei o livro vou continuar a comprar o re...  conteúdo
# 2  desculpem mas achei deprimente e não me ensino...  conteúdo
# 3  preciso saber se essa compra é do livro físico...   entrega
# 4  embora tenha gostado do livro não faz sentido ...  conteúdo

# %% [markdown]
# ___
# ### Verificando a performance do Classificador
#
# Agora você deve testar o seu classificador com a base de Testes.

# %%
lista_mensagem_teste = pd.Series(df_test.Mensagem) #pd series transforma em lista

# %%
lista_mensagem_teste = pd.Series(df_test.Mensagem)

lista_dos_splits = []
for msg in lista_mensagem_teste:
    for palavra in msg.split():
        lista_dos_splits.append(palavra)


universo = list(set(lista_dos_splits))


print(universo)

print(len(universo))
# Out:
# ['bruzetti', 'suposições', 'formatacao', 'francês', 'entediou', 'todos', 'colocar', 'haja', 'profissionais', 'ódio', 'vendo', 'vetusto', 'apelo', 'folhas', 'apelativa', 'dessa', 'acabamento', 'simplista', 'básica', 'estrutura', 'físico', 'envio', 'incluem', 'preguiçoso', 'depois', 'china', 'confiei', 'emprestadopor', 'explorando', 'horror', 'impulso', 'obra', 'xix', 'adotar', 'agradou', 'establishment', 'reais', 'próxima', 'são', 'kindler', 'assuntos', 'sagamelhor', 'midias', 'nãos', 'respeitosoeu', 'estão', 'leiam', 'descrição', 'historicidade', 'islâmicos', 'trazer', 'contatar', 'mestre', 'dinâmica', 'descaso', 'existente', 'parentes', 'comuns', 'meninas', 'significados', 'suspense', 'queimá-lo', 'porquê', 'algum', 'repeti', 'explicar', 'atenciosos', 'pela', 'completemente', 'seríssimo', 'contra', 'piscina', 'sociedades', 'alto', 'houvesse', 'descubro', 'democrático', 'humilde', 'fãs', 'abrir', 'nome', 'ficando', 'cansam', 'poderei', 'lamentável', 'autora', 'biociências', 'julgo', 'proveitoso', 'resenhas', 'estaria', 'destrui', 'aprender', 'livros', 'esquerdista', "tcc's", 'raciocínio', 'paladina', 'avó', 'filósoso', 'tenho', 'fiquei', 'confuso', 'doyle', 'jus', 'opção', 'primeiros', 'ressalvas', 'comprou', 'abaixo', 'superior', 'outra', 'juntos', 'exibe', 'científica', 'deixei', 'indico', 'alijado', 'gostar', 'formato', 'valores', 'shopping', 'compra', 'condizem', 'acabei', 'contato', 'qualidade', 'linguajar', 'atrair', 'cinza', 'schwarcz', 'faltando', 'aguardando', 'distantes', 'rasga', 'viva', 'intens', 'explica', 'ataque', 'atacar', 'menor', 'rever', 'academicas', 'fluida', 'usadas', 'devolver', 'rasa', 'pq', 'universidade', 'resto', 'atendimento', 'textos', 'comparei', 'entrevista', 'milagre', 'impíricas', 'fiscal', 'data', 'repetido', 'lindo', 'custo/benefício', 'pacientes', 'casadas', 'terra”vão', 'baixa', 'chamou', 'verdadeiramente', 'metáforas', 'técnico', 'distopias', 'teríamos', 'indo', 'dispensa', 'saber', 'ouviram', 'traz', 'renomados', 'escrever', 'força', 'conhecer', 'finas', 'apesar', 'julgamento', 'desajeitado', 'referências', 'conclusões', 'vorazes', 'emprego', 'estarem', 'maioria', 'soube', 'odiei', 'menciona', 'mente', 'implantando', 'linguiça', 'amparo', 'progressista', 'vez', 'tradução', 'doado', 'equiparar', 'colaborar', 'rainha', 'continuaçao', 'feitas', 'manter', 'recomendações', 'coleciona', 'técnicos', 'aquele', 'restante', 'irrefutáveis', 'casos', 'terceiro', 'avanço', 'ultrapassa', 'vivido', 'encharquei', 'morais', 'dias', 'my', 'pura', 'suportamos', 'queria', 'europeia', 'indisponível', 'estratégias', 'conta', 'exercício', 'uso', 'contagiado', 'momentâneas', '$4941', 'sensacionalismo', 'orelha', 'local', 'vezespara', 'autoritários', 'danificada', 'lugares', '30', 'complexo', 'votar', 'descreveu', 'trump', 'esquerda', 'css', 'finalmente', 'quanto', 'consigo', 'intenção', 'solucionáveis', 'autoconhecimento', 'prescritiva', 'possíveis', 'correta', 'sociedade', 'aumentaram', 'neste', 'vasta', 'algumas', 'pátria', 'importando', 'disponíveis', 'clássico', 'dominar', 'deficiências', '20%', 'ridículas', 'varias', 'pesquisar', 'complain', 'tecnicas', 'bate', 'seguisse', 'nele', 'sustente', 'mensagens', 'redundante', 'norteia', 'enganado', 'compilador', '2-', 'dona', 'livresca', 'estranho', 'dezembro', 'mexicano', '100%', 'baratear', 'idiota', 'empresas', 'fraco', 'baseando', 'africanos', 'acreditei', 'vida', 'arte', 'réptil', 'orientação', 'enorme', 'tática', 'obter', 'desejar', 'novamente', 'escreveu', 'situações', 'descuidado', 'prolongou', '$3990', 'crítico', 'dá', 'malta', 'outrossim', 'abandonei', 'xxi', 'da/do', 'manipular', 'aula', 'publicada', 'resultados', 'complexas', 'idéias', 'acordarmos', 'duvida', 'bibliográfica', 'facilitado', 'fala', 'tentar', 'enredo', 'miúda', 'incrível', 'democracias', '4', 'validar', 'pobre', 'continuação', 'bagaça', 'class=a-link-normal', 'adquirir', 'fontes', 'quietos', 'acima', 'enviar', '2019;', 'adivinhem', 'carvalho', 'contempla', 'afirmação', 'pesares', 'geral' ...
# 3291

# %%
universo
# Out:
# ['bruzetti',
#  'suposições',
#  'formatacao',
#  'francês',
#  'entediou',
#  'todos',
#  'colocar',
#  'haja',
#  'profissionais',
#  'ódio',
#  'vendo',
#  'vetusto',
#  'apelo',
#  'folhas',
#  'apelativa',
#  'dessa',
#  'acabamento',
#  'simplista',
#  'básica',
#  'estrutura',
#  'físico',
#  'envio',
#  'incluem',
#  'preguiçoso',
#  'depois',
#  'china',
#  'confiei',
#  'emprestadopor',
#  'explorando',
#  'horror',
#  'impulso',
#  'obra',
#  'xix',
#  'adotar',
#  'agradou',
#  'establishment',
#  'reais',
#  'próxima',
#  'são',
#  'kindler',
#  'assuntos',
#  'sagamelhor',
#  'midias',
#  'nãos',
#  'respeitosoeu',
#  'estão',
#  'leiam',
#  'descrição',
#  'historicidade',
#  'islâmicos',
#  'trazer',
#  'contatar',
#  'mestre',
#  'dinâmica',
#  'descaso',
#  'existente',
#  'parentes',
#  'comuns',
#  'meninas',
#  'significados',
#  'suspense',
#  'queimá-lo',
#  'porquê',
#  'algum',
#  'repeti',
#  'explicar',
#  'atenciosos',
#  'pela',
#  'completemente',
#  'seríssimo',
#  'contra',
#  'piscina',
#  'sociedades',
#  'alto',
#  'houvesse',
#  'descubro',
#  'democrático',
#  'humilde',
#  'fãs',
#  'abrir',
#  'nome',
#  'ficando',
#  'cansam',
#  'poderei',
#  'lamentável',
#  'autora',
#  'biociências',
#  'julgo',
#  'proveitoso',
#  'resenhas',
#  'estaria',
#  'destrui',
#  'aprender',
#  'livros',
#  'esquerdista',
#  "tcc's",
#  'raciocínio',
#  'paladina',
#  'avó',
#  'filósoso',
#  'tenho',
#  'fiquei',
#  'confuso',
#  'doyle',
#  'jus',
#  'opção',
#  'primeiros',
#  'ressalvas',
#  'comprou',
#  'abaixo',
#  'superior',
#  'outra',
#  'juntos',
#  'exibe',
#  'científica',
#  'deixei',
#  'indico',
#  'alijado',
#  'gostar',
#  'formato',
#  'valores',
#  'shopping',
#  'compra',
#  'condizem',
#  'acabei',
#  'contato',
#  'qualidade',
#  'linguajar',
#  'atrair',
#  'cinza',
#  'schwarcz',
#  'faltando',
#  'aguardando',
#  'distantes',
#  'rasga',
#  'viva',
#  'intens',
#  'explica',
#  'ataque',
#  'atacar',
#  'menor',
#  'rever',
#  'academicas',
#  'fluida',
#  'usadas',
#  'devolver',
#  'rasa',
#  'pq',
#  'universidade',
#  'resto',
#  'atendimento',
#  'textos',
#  'comparei',
#  'entrevista',
#  'milagre',
#  'impíricas',
#  'fiscal',
#  'data',
#  'repetido',
#  'lindo',
#  'custo/benefício',
#  'pacientes',
#  'casadas',
#  'terra”vão',
#  'baixa',
#  'chamou',
#  'verdadeiramente',
#  'metáforas',
#  'técnico',
#  'distopias',
#  'teríamos',
#  'indo',
#  'dispensa',
#  'saber',
#  'ouviram',
#  'traz',
#  'renomados',
#  'escrever',
#  'força',
#  'conhecer',
#  'finas',
#  'apesar',
#  'julgamento',
#  'desajeitado',
#  'referências',
#  'conclusões',
#  'vorazes',
#  'emprego',
#  'estarem',
#  'maioria',
#  'soube',
#  'odiei',
#  'menciona',
#  'mente',
#  'implantando',
#  'linguiça',
#  'amparo',
#  'progressista',
#  'vez',
#  'tradução',
#  'doado',
#  'equiparar',
#  'colaborar',
#  'rainha',
#  'continuaçao',
#  'feitas',
#  'manter',
#  'recomendações',
#  'coleciona',
#  'técnicos',
#  'aquele',
#  'restante',
#  'irrefutáveis',
#  'casos',
#  'terceiro',
#  'avanço',
#  'ultrapassa',
#  'vivido',
#  'encharquei',
#  'morais',
#  'dias',
#  'my',
#  'pura',
#  'suportamos',
#  'queria',
#  'europeia',
#  'indisponível',
#  'estratégias',
#  'conta',
#  'exercício',
#  'uso',
#  'contagiado',
#  'momentâneas',
#  '$4941',
#  'sensacionalismo',
#  'orelha',
#  'local',
#  'vezespara',
#  'autoritários',
#  'danificada',
#  'lugares',
#  '30',
#  'complexo',
#  'votar',
#  'descreveu',
#  'trump',
#  'esquerda',
#  'css',
#  'finalmente',
#  'quanto',
#  'consigo',
#  'intenção',
#  'solucionáveis',
#  'autoconhecimento',
#  'prescritiva',
#  'possíveis',
#  'correta',
#  'sociedade',
#  'aumentaram',
#  'neste',
#  'vasta',
#  'algumas',
#  'pátria',
#  'importando',
#  'disponíveis',
#  'clássico',
#  'dominar',
#  'deficiências',
#  '20%',
#  'ridículas',
#  'varias',
#  'pesquisar',
#  'complain',
#  'tecnicas',
#  'bate',
#  'seguisse',
#  'nele',
#  'sustente',
#  'mensagens',
#  'redundante',
#  'norteia',
#  'enganado',
#  'compilador',
#  '2-',
#  'dona',
#  'livresca',
#  'estranho',
#  'dezembro',
#  'mexicano',
#  '100%',
#  'baratear',
#  'idiota',
#  'empresas',
#  'fraco',
#  'baseando',
#  'africanos',
#  'acreditei',
#  'vida',
#  'arte',
#  'réptil',
#  'orientação',
#  'enorme',
#  'tática',
#  'obter',
#  'desejar',
#  'novamente',
#  'escreveu',
#  'situações',
#  'descuidado',
#  'prolongou',
#  '$3990',
#  'crítico',
#  'dá',
#  'malta',
#  'outrossim',
#  'abandonei',
#  'xxi',
#  'da/do',
#  'manipular',
#  'aula',
#  'publicada',
#  'resultados',
#  'complexas',
#  'idéias',
#  'acordarmos',
#  'duvida',
#  'bibliográfica',
#  'facilitado',
#  'fala',
#  'tentar',
#  'enredo',
#  'miúda',
#  'incrível',
#  'democracias',
#  '4',
#  'validar',
#  'pobre',
#  'continuação',
#  'bagaça',
#  'class=a-link-normal',
#  'adquirir',
#  'fontes',
#  'quietos',
#  'acima',
#  'enviar',
#  '2019;',
#  'adivinhem',
#  'carvalho',
#  'contempla',
#  'afirmação',
#  'pesares',
#  'geral',
#  'vieram',
#  'personalidade',
#  'porem',
#  'compro',
#  'alberto',
#  'funcionando',
#  'disponibilidade',
#  'vêem',
#  'baseadas',
#  'critério',
#  'redirecionam',
#  'informações',
#  'meus',
#  'os',
#  'joguei',
#  'decepção',
#  '0712',
#  'último',
#  'estabelecimentos',
#  'seus',
#  'respondo',
#  'felizes',
#  'xingam',
#  'cópia',
#  'somente',
#  'repetitivos',
#  'amazoncom',
#  'substancial',
#  'apresenta',
#  'confiável',
#  'bobagem',
#  'auto-responsabilidade',
#  'única',
#  'curto',
#  'decisão',
#  'nesse',
#  'preferências',
#  'relação',
#  'encheu',
#  'lateral',
#  'sombra',
#  'falando',
#  'atrapalha',
#  'retirado',
#  'peca',
#  'junho',
#  'completo',
#  'português',
#  'sinopse',
#  'obras',
#  'vocês',
#  'comparar',
#  'aumentar',
#  'enviei',
#  'qualquer',
#  'notei',
#  'deseje',
#  'desapontada',
#  'nítido',
#  'ossos',
#  'presente',
#  'tomos',
#  'devorando-o',
#  'argumentações',
#  'desde',
#  'ridículo',
#  'dos',
#  'negócios',
#  'foi',
#  'ora',
#  'trouxe',
#  'merecidamente',
#  'avaliar',
#  'decorativo',
#  'foto',
#  'charlatão',
#  'catolicismo',
#  'mãos',
#  'amargurada',
#  'l',
#  'coleção',
#  'formatados',
#  'grata',
#  'comprar',
#  'fiz',
#  'fixar',
#  'recebir',
#  'rechear',
#  'sensacionalista',
#  'receber',
#  'sofreram',
#  'moleque',
#  'conter',
#  'paulo',
#  'descobrirem',
#  'terminar',
#  'produtividade',
#  'semanas',
#  'limitante',
#  'munição',
#  'finge',
#  'ele',
#  'absurda',
#  'somam',
#  'levar',
#  'i',
#  'portos',
#  'trabalhar',
#  'evitando',
#  'do/a',
#  'mulheres',
#  'sitemarketing',
#  'várias',
#  'solução',
#  'título',
#  'diversos',
#  'danos',
#  'adolescente',
#  'afirma',
#  'especializado',
#  'feito',
#  'cliente',
#  'dependencia',
#  'ranhuras',
#  'citar',
#  'access',
#  'mega',
#  'válidas',
#  'precisava',
#  'daquela',
#  'diferença',
#  'mensagem',
#  'grudada',
#  'sorte',
#  'feminista',
#  'site',
#  'infeliz',
#  'assistir',
#  'amareladas',
#  'vagas',
#  'intelectuais',
#  'qts',
#  'chama',
#  'sequencia',
#  'próprio',
#  'descascada',
#  'pretos',
#  'assertivas',
#  'áreas',
#  'talvez',
#  'superounão',
#  'maiores',
#  'gosta',
#  'brinde',
#  'individual',
#  'narrativa',
#  'deve-se',
#  'possui',
#  'liga',
#  'mentalizar',
#  'sério',
#  'repetitiva',
#  'geralmente',
#  'deles',
#  'aproveitar',
#  'assumir',
#  'filmes',
#  'exceção',
#  'autoestima',
#  'leitores',
#  'lances',
#  'inteligente',
#  'descascando',
#  'sem',
#  'will',
#  'encomenda',
#  'cheia',
#  'passar',
#  'quiser',
#  'ilíada',
#  'dourados',
#  'reembolso',
#  'vir',
#  'paisagem',
#  'costuma',
#  'preconceituoso',
#  'utiliza',
#  'alterar',
#  'direção',
#  'encontram-se',
#  'aquela',
#  'perceberão',
#  'passável',
#  'prega',
#  'democráticos',
#  'visão',
#  'colocam',
#  'inicia',
#  'palestras',
#  'software',
#  'emoções',
#  'será',
#  'relembrando',
#  'carregar',
#  'auxiliaram',
#  'respondesse',
#  'brasileiro',
#  'brinquedos',
#  'débito',
#  'dostoiévski',
#  'james',
#  'faculdade',
#  'seria',
#  'tronos',
#  'efetivamente',
#  'anunciar',
#  'experiente',
#  'vei',
#  'embarcar',
#  'blog',
#  'devolvo',
#  'relações',
#  'oitocentas',
#  'gostaria',
#  'na',
#  'conveniente',
#  'porque',
#  'it',
#  'amante',
#  'engraçado',
#  'velha',
#  'espantoso',
#  'clientes',
#  'acrescentou',
#  'capitulo',
#  'repetição',
#  'acredito',
#  'carlos',
#  'nossos',
#  'sites',
#  'média',
#  'pequenos',
#  'prestar',
#  'populares',
#  'este',
#  'mão',
#  'inscritos',
#  'religiões',
#  'custos',
#  'volta',
#  'escolhi',
#  'veja',
#  'nas',
#  'dobrada',
#  'porcaria',
#  'vou',
#  'responsabilidade',
#  'interminadoesperamos',
#  'econômicas',
#  'sido',
#  'mínimo',
#  'limites',
#  'embalaram',
#  'senso',
#  'demagogia',
#  'anos',
#  'filhas',
#  'papo',
#  'geram',
#  'popularização',
#  'especulativos',
#  'felipe',
#  'enganador',
#  'incluindo',
#  'demais',
#  'perderam',
#  'chimpanzés;',
#  'lugar',
#  'cortadas',
#  'ditador',
#  'original',
#  'ds',
#  'imaginava',
#  'adquiri',
#  'brincava',
#  'ação',
#  'primata',
#  'cer',
#  'preço',
#  'nenhuma',
#  'materiais',
#  'criou',
#  'amassados',
#  'vontade',
#  'concluir',
#  'eram',
#  'reflexões',
#  'prometeu',
#  'gideon',
#  'alem',
#  'fino',
#  'editada',
#  'praticados',
#  'tom',
#  'descancaradamente',
#  'manutenção',
#  'maravilhosa',
#  'trata',
#  'sentiria',
#  'poemas',
#  'cala-a-boca',
#  'bolsonaro',
#  'bons',
#  'otário',
#  'morar',
#  'dia',
#  'porta',
#  'assumi',
#  'valioso',
#  'pobreza',
#  'bobosodiei',
#  'industria',
#  'amaram',
#  'aos',
#  'resumo',
#  'ideais',
#  'última',
#  'paga',
#  'históriaé',
#  'importantes',
#  'unavailable',
#  'panfleto',
#  'ambos',
#  'vertical',
#  'desenvolvido',
#  'atestando',
#  'jeito',
#  'definitivamente',
#  'recomendo',
#  'propósito',
#  'venho',
#  'interessem',
#  'texto',
#  'fizeram',
#  'remédio',
#  'concordância',
#  'confirmação',
#  'disposta',
#  'histórias',
#  'culpa',
#  'principal',
#  'vamos',
#  'facilidade',
#  'positivo',
#  'sistemática',
#  'garota',
#  'economiza',
#  'oferecido',
#  'tinta',
#  'corrigido',
#  'perdeu',
#  'segundo',
#  'douradas',
#  'versos',
#  'muita',
#  'especializada',
#  'grey',
#  'aumento',
#  'trey',
#  'decente',
#  'toda',
#  'rita',
#  'meninada',
#  'inúmeros',
#  'directamente',
#  'ajudando',
#  'um',
#  'dobradas',
#  'iria',
#  'impressionar',
#  'específico',
#  'estao',
#  'versão',
#  'contemporânea',
#  'pro',
#  'aeroportos',
#  'excelentes',
#  'adolescentes',
#  'orangotangos',
#  'insignificantes',
#  'violência',
#  "''comidas''",
#  'nessas',
#  'torna',
#  'apenas',
#  'fatura',
#  'tiverem',
#  'dores',
#  '4192',
#  'terceira',
#  'imaginação',
#  'msm',
#  'estiver',
#  'esses',
#  'diversas',
#  'jacket',
#  'daria',
#  'científico',
#  'nesta',
#  '0',
#  'teve',
#  'ao',
#  'senhor',
#  'contextualização',
#  'palavras',
#  'cria',
#  'prendeu',
#  'ideal',
#  'venda',
#  'esteje',
#  'eles',
#  'diferenças',
#  'rasgada',
#  'obviamente',
#  'is',
#  'três',
#  'arrasou',
#  'letras',
#  'parecem',
#  'proposital',
#  'diferentes',
#  'isto',
#  'seleção',
#  'valor',
#  'laboratórios',
#  'terminam',
#  'aliviada',
#  'sorry',
#  'envolvidos',
#  'principalmente',
#  'conviver',
#  'partir',
#  '3-',
#  'amaçada',
#  'embora',
#  'frio',
#  'axioma',
#  'show',
#  'enfadonhas',
#  '“mitos',
#  'demoraria',
#  'apendice',
#  'atendeu',
#  'decepciona',
#  'procurar',
#  'daenerys',
#  'reflexão',
#  'jovens',
#  'pal-avras',
#  'emplastificado',
#  'pronto',
#  'perda',
#  'latino-americanos',
#  'presenteei',
#  'avaliado',
#  'desnecessária',
#  'livro',
#  'poucas',
#  '140',
#  'comercial',
#  'recompensa',
#  'deseduca',
#  'acaba',
#  'melhor',
#  'ledo',
#  'r$12000',
#  'refletir',
#  'gostado',
#  'macacos',
#  'contas',
#  'mim',
#  'você',
#  'material',
#  '<a',
#  'anterior',
#  'sequência',
#  'representam',
#  'lançado',
#  'amassado',
#  'prático',
#  'para',
#  'motivacionais',
#  'deturpa',
#  'mudança',
#  'jogaram',
#  'oculto',
#  'técnicas',
#  'interpreto',
#  '219',
#  'próximo',
#  'tendo',
#  'elaborado',
#  'aborda',
#  'indignado',
#  'humanos',
#  'peso',
#  'danificou',
#  'dois',
#  'pesada',
#  'questão',
#  'naquele',
#  'pregar',
#  'pnl',
#  'pensei',
#  'petitiivas',
#  'falta',
#  'adorei',
#  'objetivo',
#  'lástima',
#  'móveis',
#  'empregas',
#  'gostei',
#  'esquecendo',
#  'horrivelmente',
#  'mencionada',
#  'seriamente',
#  'brevemente',
#  'agora',
#  'pode',
#  'democratas',
#  'impressão',
#  'comparem',
#  '1',
#  'crossfire',
#  'tranquilamente',
#  'já',
#  'consideradao',
#  'walter',
#  'incutir',
#  'livreto',
#  '194195198199202203206207210211214215',
#  'variar',
#  'resolver',
#  'existem',
#  'coloca',
#  'jatinho',
#  'drasticamente',
#  '7',
#  'perguntar',
#  'subjetiva',
#  'ia',
#  'achismo',
#  'estornaram',
#  'vistas',
#  'bobear',
#  'horrivel',
#  'marcando',
#  'também',
#  'alteração',
#  'carros',
#  'irreal',
#  'pouco',
#  'digo',
#  'alguém',
#  'casar',
#  'descritivo',
#  'consegui',
#  'telefone',
#  'sexualmente',
#  'lote”;',
#  'segunda',
#  'acessar',
#  'substituir',
#  'quase',
#  'pseudo-ciênciatem',
#  'exalam',
#  'proposta',
#  'meios',
#  'presentear',
#  'separa',
#  'olho',
#  'pesquisares',
#  'visto',
#  'chegando',
#  'acontece',
#  'all',
#  'coma',
#  'guarda',
#  'coaching',
#  'lista',
#  'irmãos',
#  '80/20',
#  'theon',
#  'exploram',
#  'destes',
#  'plástico',
#  'frustração',
#  'alemão',
#  'embrulho',
#  'no',
#  'dormir',
#  'narrativo',
#  'riqueza',
#  'saudoso',
#  'apresentados',
#  'saiu',
#  'quando',
#  'pseudo',
#  '2015',
#  'perguntando',
#  'esticar',
#  'aguenta',
#  '20',
#  'câmara',
#  'honesto',
#  'rola',
#  'achando',
#  'envolvida',
#  'física',
#  'perdido',
#  'elena',
#  'alias',
#  'ignora',
#  'disse',
#  'gastaria',
#  'artigo',
#  'cito',
#  'traduzindo',
#  'normal',
#  'faço',
#  'amigos',
#  'bonitos',
#  'fina',
#  '😤',
#  'primeiramente',
#  'abuso',
#  'trocou',
#  'explicações',
#  'trásse',
#  'debitaram',
#  'cristã',
#  'regras',
#  'criança',
#  'chamá-lo',
#  'reeducação',
#  'estória',
#  'expressar',
#  'enfim',
#  ...]

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# ___
# ### Qualidade do Classificador a partir de novas separações dos tweets entre Treinamento e Teste
#
# Caso for fazer esse item do Projeto

# %% [markdown]
# ___
# ## Aperfeiçoamento:
#
# Trabalhos que conseguirem pelo menos conceito B vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * IMPLEMENTOU outras limpezas e transformações que não afetem a qualidade da informação contida nos tweets. Ex: stemming, lemmatization, stopwords
# * CONSIDEROU mais de duas categorias na variável Target e INCREMENTOU a quantidade de notícias, mantendo pelo menos 250 notícias por categoria (OBRIGATÓRIO PARA TRIOS, sem contar como item avançado)
# * Para Target com duas categorias: CRIOU pelo menos quatro categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante
# * EXPLICOU porquê não pode usar o próprio classificador para gerar mais amostras de treinamento
# * PROPÔS diferentes cenários para Naïve Bayes fora do contexto do projeto (pelo menos dois cenários, exceto aqueles já apresentados em sala pelos professores: por exemplo, filtro de spam)
# * SUGERIU e EXPLICOU melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)
# * FEZ o item Qualidade do Classificador a partir de novas separações das Notícias entre Treinamento e Teste descrito no enunciado do projeto (OBRIGATÓRIO para conceitos A ou A+)

# %% [markdown]
# ___
# ## Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
