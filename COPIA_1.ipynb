# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Caio Monteiro Marquez Barbosa
# Felipe Bakowski Nantes de Souza
# Lucas Santos Teixeira

# %% [markdown]
# Atenção: Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# Carregando algumas bibliotecas:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# c:\Users\Felipe\Desktop\CdaDos_P1

# %% [markdown]
# Carregando a base de dados com os tweets classificados manualmente:

# %%
train = pd.read_excel('dados_treino_copia.xlsx')
train.head(5)
# Out:
#                                             Mensagem  Unnamed: 1  Unnamed: 2  \
# 0  Um dos livros faltam mais de 40 páginas. Ex.: ...         NaN         NaN
# 1  O livro é incompleto. Acaba em 11/04/44, sendo...         NaN         NaN
# 2  Ainda não terminei, estou nos 40%, devo ler em...         NaN         NaN
# 3  Pedi o livro baseado na promoção q era de graç...         NaN         NaN
# 4  Prezados, Acredito que houve um erro, pois des...         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  ...  Unnamed: 87  Unnamed: 88  Unnamed: 89  Unnamed: 90  \
# 0         NaN  ...          NaN          NaN          NaN          NaN
# 1         NaN  ...          NaN          NaN          NaN          NaN
# 2         NaN  ...          NaN          NaN          NaN          NaN
# 3         NaN  ...          NaN          NaN          NaN          NaN
# 4         NaN  ...          NaN          NaN          NaN          NaN
#
#    Unnamed: 91  Unnamed: 92  Unnamed: 93  Unnamed: 94  Unnamed: 95    Target
# 0          NaN          NaN          NaN          NaN          NaN   entrega
# 1          NaN          NaN          NaN          NaN          NaN   entrega
# 2          NaN          NaN          NaN          NaN          NaN  conteúdo
# 3          NaN          NaN          NaN          NaN          NaN     preço
# 4          NaN          NaN          NaN          NaN          NaN     preço
#
# [5 rows x 97 columns]

# %%
test = pd.read_excel('dados_teste_copia.xlsx')
test.head(5)
# Out:
#                                             Mensagem  Unnamed: 1  Unnamed: 2  \
# 0  a narrativa é muito lenta e você fica ansioso ...         NaN         NaN
# 1  Sim.adorei o livro Vou continuar a comprar o r...         NaN         NaN
# 2  Desculpem, mas achei deprimente e não me ensin...         NaN         NaN
# 3  Preciso saber se essa compra é do livro físico...         NaN         NaN
# 4  Embora tenha gostado do livro "Não Faz Sentido...         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  ...  Unnamed: 33  Unnamed: 34  Unnamed: 35 Unnamed: 36  \
# 0         NaN  ...          NaN          NaN          NaN         NaN
# 1         NaN  ...          NaN          NaN          NaN         NaN
# 2         NaN  ...          NaN          NaN          NaN         NaN
# 3         NaN  ...          NaN          NaN          NaN         NaN
# 4         NaN  ...          NaN          NaN          NaN         NaN
#
#    Unnamed: 37  Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41    Target
# 0          NaN          NaN          NaN          NaN          NaN  conteúdo
# 1          NaN          NaN          NaN          NaN          NaN  conteúdo
# 2          NaN          NaN          NaN          NaN          NaN  conteúdo
# 3          NaN          NaN          NaN          NaN          NaN   entrega
# 4          NaN          NaN          NaN          NaN          NaN  conteúdo
#
# [5 rows x 43 columns]

# %% [markdown]
# ___
# ## Classificador automático

# %% [markdown]
# Faça aqui uma descrição do seu assunto e o que considerou como relevante ou não relevante na classificação dos tweets (Target).
#
# ESCREVA AQUI...

# %% [markdown]
# ___
# ### Montando um Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %%
df_train = train['Mensagem'].to_frame()
df_train['Target'] = train['Target']

df_test = train['Mensagem'].to_frame()
df_test['Target'] = train['Target']

# %%
caracteres = [':',',','.','(',')', '?', '!', '"']
i = 0
for msg in df_train.Mensagem:
    for caractere in caracteres:
        if caractere in msg:
            msg = msg.replace(caractere, '')
            msg = msg.lower()
    df_train.loc[i, 'Mensagem'] = msg 
    i += 1
    
    
j = 0
for msg in df_train.Mensagem:
    for caractere in caracteres:
        if caractere in msg:
            msg = msg.replace(caractere, '')
            msg = msg.lower()
    df_test.loc[j, 'Mensagem'] = msg 
    j += 1

# %%
lista_mensagem_teste = pd.Series(df_train.Mensagem) #pd series transforma em lista

# %%
#criando o conjunto universo de palavras
lista_mensagem_teste = pd.Series(df_train.Mensagem)

lista_dos_splits = []
for msg in lista_mensagem_teste:
    for palavra in msg.split():
        lista_dos_splits.append(palavra)


universo = list(set(lista_dos_splits))


print(universo)

print(len(universo))
# Out:
# ['apareceram', 'progressistas', 'livrar', 'absurdas', 'islã', 'ato', 'solucao', 'parecendo', 'diagramado', 'l', 'marco', 'atrás', 'autora', 'subjugar', 'jogo', 'daria', 'estorno', 'sob', 'estão', 'poema', 'rodeios', 'letvinsky', 'gastam', 'incomuns', 'expectativa', 'mim', 'agnósticos', 'desgraça', 'esperando', 'banco', 'premiada', 'pedi', 'pitadinhas', 'blog', 'investir', 'corrido', 'descartado', 'proteção', '2008', 'madalena', 'leonpríncipe', 'compram', 'duplicadas', 'natal', 'expostas', 'refere-se', 'instituições', 'retirar', 'pauto', 'restringirá', 'greve', 'contra', 'retorna', 'constantes', 'tem', 'pulando', 'intitula', 'conforme', 'nomes', 'concluí', 'pq', 'sí', 'livrechama', 'quebrando', 'olhem', 'sofredora', 'língua', 'extremamente', 'índice', 'subtítulo', 'aproveitável', 'folha', 'minúscula', 'amor', 'cabem', 'criptoanálise', 'precisava', 'reclamam', 'reviravoltas', 'leva', 'correta', 'eg', 'significasse', 'infantis', 'barato', 'guardados', 'incomodado', 'dedo', 'polindo', 'decepcão', 'cogita', 'faltantes', 'triste', 'arranhada/rasgada', 'virtual', 'internet', 'defender', 'editorial', 'várias', 'serviço', 'coachingexistem', 'lendo', 'novamento', 'máximo', 'percebe-se', '7', 'agremiações', 'detalhada', 'agradou', 'ô', 'passamos', 'parágrafos', 'cancelar', 'desencoraja', 'tediosa', 'absoluta', 'gostando', 'sensacionalista', 'aconselho', 'divertido', 'seguida', 'determinado', 'diálogos', 'não', '99', 'repetição', 'ler', 'macartismo', 'sengido', 'desenvolvido', 'lancado', 'ele', 'enchimento', 'chanceler', 'ex-membro', 'morto', 'opção', 'ex-marido', 'inventores', 'genial', 'média', 'estupros', 'tradução', 'exemplo', 'reflexivos', 'concluídos', 'sofia', 'rasgadas', 'denúncias', 'escanearam', 'rachel', 'deixando', 'salazar', 'aconteceu', 'agradaram', 'texto', 'queria', 'dava', 'comenta', 'campbell', 'jorge', 'romântico', 'temas', 'ricos', 'levando', 'junto', 'objetiva', 'da', 'dessa', 'passou', 'coagir', 'alguem', 'formadas', 'nessa', 'sul', 'alemanha', 'consegue', 'possamos', 'quiser', 'extrair', 'romantiza', 'conotação', 'hifenizadas', 'luto', 'encher', 'profissional', 'repetidas', 'descritivas', 'segue', 'best', 'delas', 'r', 'criticar', 'taxado', 'puxa', 'leitura', 'queda', 'verifiquei', 'chegada', 'amei', 'identificar', 'anunciaram', 'despertou', 'redimir', 'popular', 'nazista', 'devastadores', 'socialista', 'cm', 'grito', 'conteudo', 'lingüiça', 'autoestima', 'deturpação', 'desgosto', 'rebatia', 'negros', 'continuam', 'sintoma', 'barata', 'superficialidade', 'e-books', 'enredo', 'impossível', 'tinha', 'original', 'faculdade', 'discussão', 'danificadas', 'maldita', 'historietas', 'dos', 'partir', 'negar', 'notei', 'grata', 'atrela', 'tradutor', 'economizar', 'ideais', 'service', 'excluir', 'burocracia', 'monumental', 'deveriam', 'argumentações', 'prefeitos', 'vazias', 'saudável', 'comprados', 'para', 'cenário', 'moral', 'deparo', 'gustave', 'provou', 'negócio', '545', 'radicais', 'quiçá', 'compilação', 'transmitir', 'psíquica', 'fala', 'contextualizando', 'xerox', 'medíocre', 'tio', 'desenvolvimento', 'dobro', 'manipulando', 'tecnologia', 'descontaram', 'bela', 'pensam', 'feliz', 'desafia', 'sofreu', 'recém', 'masculino', 'olhar', 'otimo', 'abs', 'fazia', 'martinsconsiderada', 'descreve', 'ciencia', 'sua', 'cada', 'comentários', 'snow', 'análise', 'pena', 'matou', 'morre', 'fazendo', 'info', 'surgiram', 'boas', 'comprovei', 'certinha', 'identifique', 'colocarem', 'técnica', 'serviu', 'barbaridades', 'lu', 'entender', 'melhorar', 'aplausos', 'acontecido', 'falando', 'generalista', 'teresa', 'abuso', 'entregas', 'errou', 'instituído', 'luxoo', 'entretanto', 'contei', 'sem', 'funcionam', 'servem', 'achismos', 'tratado', 'piadas', 'mudadas', 'domínio', 'crônicas', 'papel', 'enganada', 'três', 'issacson', 'nação', 'sono', 'ta', 'feministas', 'marcadores', 'termos', 'compreensão', 'darkside', 'obs', 'horrivel', 'tenham', 'ignaros', 'tentei', 'sulerficial', 'significa', 'famoso', 'cor', 'de', 'local', 'hã', 'compra', 'palpavel' ...
# 5097

# %%
#criando o conjunto de palavras de entrega
livro_conteudo = ''
df_train_conteudo = df_train.loc[(df_train.Target == 'conteúdo')]
for msg in df_train_conteudo.Mensagem:
    livro_conteudo += msg

# %%
livro_entrega = ''
df_train_entrega = df_train.loc[(df_train.Target == 'entrega')]
for msg in df_train_entrega.Mensagem:
    livro_entrega += msg

# %%
livro_preco = ''
df_train_preco = df_train.loc[(df_train.Target == 'preço')]
for msg in df_train_preco.Mensagem:
    livro_preco += msg

# %%
livro_geral = livro_entrega + livro_conteudo + livro_preco

# %%
livro_geral
# Out:
# "um dos livros faltam mais de 40 páginas ex pula da pág 140 pra pág 193 como foi um presente e a pessoa só viu quando estava lendo essa parte perdemos o prazo de devoluçãoo livro é incompleto acaba em 11/04/44 sendo que o diário dela foi escrito até 01/08/44 alguém pode explicar pq não informam que é incompletoVeio amassado nas pontasoh amazon por favor atualiza essa edição está sem condição de ler faltam frases dos personagens diálogos tem pedaço do livro que não da nem pra entender o que está acontecendogostei do acabamento do livro porém podia ser em paginas amareladas o livro tem uma gama de palavras em outra língua e o glossário fica na parte de trás logo fica uma leitura não muito dinâmicano ato da minha compra na descrição do produto não constava que o mesmo era um livro de bolso muito pelo contrário as dimensões do produto eram outras se eu estivesse no endereço quando o produto foi entregue teria devolvido o mesmo sem pestanejar infelizmente estava de férias e acabei perdendo o prazo de devolução outra observação que tenho a fazer é em relação ao zelo pelos produtos embalados os funcionários da amazon pesaram a mão nas minhas últimas entregas pois praticamente todos os livros contêm leves amassados em suas bordas fica aqui a minha indignação com a amazono pedido veio rápido os livros são maravilhosos porém o box veio em péssimas condições parece que caiu água nele e estufou todo o material como mostram as imagens as pontas estão destruídas com certeza caiu no chão em algum momento estou frustrada com a minha primeira aquisição na amazonentrega bem rápidamas tanto a caixaquanto as laterias dos livros vieram um pouco danificadascom pequenas marcaso plástico que vinha para protegertambém já estava um pouco rasgadoo volume 5 esta com erro tem impressão tem paginas duplicada e outras faltandoadquiri a edição comemorativa na verdade uma edição econômica extremamente mal feita 4a edição 2015 papel de baixa gramatura péssima encadernação as folhas estão desalinhadas há cola na lombada e a fonte utilizada bem  a fonte utlizada é um total desrespeito ao leitor muito pequena torna a leitura um esforço ao colocar esse produto no mercado a editora leya comete abuso um desrespeito aos leitores e à obra em si lamentável vergonhososupostamente baixei este livro gratis apos uma promoçao de vocês mas na verdade o download não foi realizado houvr algun problemabaixei a amostra e não consigo comprar a versão completa porque está indisponível entrei em contato com editora e fui informada que o problema está na página da loja amazon e que seria normalizado até o presente momento não houve mudança já tem dois meses que estou aguardando e aí amazon quando será normalizadocomprei no lançamento o livro e mais completo essa segunda edição tem paginas a menos em comparação ao outro faltou conteúdoachei muito merchandising e pouco conteúdo prático os conteúdos ficam em um site e não no livro sinto que desperdicei meu dinheiro com o livro já que no site o conteúdo é gratuito  além disso tem muitas histórias pessoais e relatos sobre como o milagre é incrível e pouco sobre o milagreeu também cheguei a entrar na página para comprar o livro em questão porém com avaliações como estas desisti da compra acho um absurdo uma empresa como a amazon estar envolvida com pirataria ou mesmo comercializando um material incorreto fraudulento e por sua vez desrespeitando o consumidor absurdoprimeiramente meu pedido nem veiomas me reembolsaramfavor corrigir a formatação do livro pois está péssimo para ler não sendo possível ler na forma que está  portanto espero que a amzon corrija este livro que parece ser brilhante a literatura em si não há o que contestar um épico  porém a propaganda é enganosa quando cita  obra ilustrada na verdade o que tem é um pequeno encarte com algumas ilustrações completamente fora do contexto dos cantos o que torna a leitura truncada se você quer acompanhar o texto junto a ilustração  neste sentido foi muito frustante adquirir a divina co ...

# %%
#estudo de frequência 
serie_geral = pd.Series(livro_geral.split())
tabela_geral = serie_geral.value_counts()
tabela_geral
# Out:
# de             837
# o              803
# que            794
# e              757
# a              733
#               ...
# ocuparam         1
# acham            1
# livrar           1
# entregaram       1
# distorcidos      1
# Length: 5405, dtype: int64

# %%
serie_conteudo = pd.Series(livro_conteudo.split())
tabela_conteudo = serie_conteudo.value_counts()
tabela_conteudo
# Out:
# de              627
# que             562
# e               530
# o               520
# a               480
#                ...
# determinadas      1
# coitada           1
# explicação        1
# fracomuitas       1
# psicológica       1
# Length: 4241, dtype: int64

# %%
serie_entrega = pd.Series(livro_entrega.split())
tabela_entrega = serie_entrega.value_counts()
tabela_entrega
# Out:
# o                 263
# a                 233
# que               211
# e                 209
# de                186
#                  ...
# leituraatender      1
# espaço              1
# desconfigurado      1
# espaçamento         1
# persistente         1
# Length: 1950, dtype: int64

# %%
serie_preco = pd.Series(livro_preco.split())
tabela_preco = serie_preco.value_counts()
tabela_preco
# Out:
# de         24
# que        21
# o          20
# a          20
# e          18
#            ..
# algum       1
# desenho     1
# cor         1
# sem         1
# aqui        1
# Length: 369, dtype: int64

# %%
#suavizador
dicionario_de_prob_palavra_tal_entrega = dict()
for frase in df_train['Mensagem']:
    for palavra in frase.split():
        if palavra in tabela_entrega:
            if palavra not in dicionario_de_prob_palavra_tal_entrega:
                dicionario_de_prob_palavra_tal_entrega[palavra] = (tabela_entrega[palavra]+1)/(len(livro_geral.split()) + len(universo))
            else:
                dicionario_de_prob_palavra_tal_entrega[palavra] += (tabela_entrega[palavra]+1)/(len(livro_geral.split()) + len(universo))
        else:
            if palavra not in dicionario_de_prob_palavra_tal_entrega:
                dicionario_de_prob_palavra_tal_entrega[palavra] = 1/(len(livro_geral.split()) + len(universo))
            else:
                dicionario_de_prob_palavra_tal_entrega[palavra] += 1/(len(livro_geral.split()) + len(universo))


dicionario_de_prob_palavra_tal_conteudo = dict()
for frase in df_train['Mensagem']:
    for palavra in frase.split():
        if palavra in tabela_conteudo:
            if palavra not in dicionario_de_prob_palavra_tal_conteudo:
                dicionario_de_prob_palavra_tal_conteudo[palavra] = (tabela_conteudo[palavra]+1)/(len(livro_geral.split()) + len(universo))
            else:
                 dicionario_de_prob_palavra_tal_conteudo[palavra] += (tabela_conteudo[palavra]+1)/(len(livro_geral.split()) + len(universo))
        else:
            if palavra not in dicionario_de_prob_palavra_tal_conteudo:
                dicionario_de_prob_palavra_tal_conteudo[palavra] = 1/(len(livro_geral.split()) + len(universo))
            else:
                dicionario_de_prob_palavra_tal_conteudo[palavra] += 1/(len(livro_geral.split()) + len(universo))

dicionario_de_prob_palavra_tal_preco = dict()
for frase in df_train['Mensagem']:
    for palavra in frase.split():
        if palavra in tabela_preco:
            if palavra not in dicionario_de_prob_palavra_tal_preco:
                dicionario_de_prob_palavra_tal_preco[palavra] = (tabela_preco[palavra]+1)/(len(livro_geral.split()) + len(universo))
            else:
                 dicionario_de_prob_palavra_tal_preco[palavra] += (tabela_preco[palavra]+1)/(len(livro_geral.split()) + len(universo))
        else:
            if palavra not in dicionario_de_prob_palavra_tal_preco:
                dicionario_de_prob_palavra_tal_preco[palavra] = 1/(len(livro_geral.split()) + len(universo))
            else:
                dicionario_de_prob_palavra_tal_preco[palavra] += 1/(len(livro_geral.split()) + len(universo))

# %%
#classificador

# %% [markdown]
# ___
# ### Verificando a performance do Classificador
#
# Agora você deve testar o seu classificador com a base de Testes.

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# ___
# ### Qualidade do Classificador a partir de novas separações dos tweets entre Treinamento e Teste
#
# Caso for fazer esse item do Projeto

# %% [markdown]
# ___
# ## Aperfeiçoamento:
#
# Trabalhos que conseguirem pelo menos conceito B vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * IMPLEMENTOU outras limpezas e transformações que não afetem a qualidade da informação contida nos tweets. Ex: stemming, lemmatization, stopwords
# * CONSIDEROU mais de duas categorias na variável Target e INCREMENTOU a quantidade de notícias, mantendo pelo menos 250 notícias por categoria (OBRIGATÓRIO PARA TRIOS, sem contar como item avançado)
# * Para Target com duas categorias: CRIOU pelo menos quatro categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante
# * EXPLICOU porquê não pode usar o próprio classificador para gerar mais amostras de treinamento
# * PROPÔS diferentes cenários para Naïve Bayes fora do contexto do projeto (pelo menos dois cenários, exceto aqueles já apresentados em sala pelos professores: por exemplo, filtro de spam)
# * SUGERIU e EXPLICOU melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)
# * FEZ o item Qualidade do Classificador a partir de novas separações das Notícias entre Treinamento e Teste descrito no enunciado do projeto (OBRIGATÓRIO para conceitos A ou A+)

# %% [markdown]
# ___
# ## Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
