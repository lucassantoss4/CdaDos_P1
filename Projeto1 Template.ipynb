# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Caio Monteiro Marquez Barbosa
# Felipe Bakowski Nantes de Souza
# Lucas Santos Teixeira

# %% [markdown]
# Atenção: Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# Carregando algumas bibliotecas:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# c:\Users\caioj\OneDrive - Insper - Institudo de Ensino e Pesquisa\2 semestre\C. Dados\projeto 1\CdaDos_P1-1

# %% [markdown]
# Carregando a base de dados com os tweets classificados manualmente:

# %%
train = pd.read_excel('dados_treino.xlsx')
train.head(5)
# Out:
#                                             Mensagem  Unnamed: 1  Unnamed: 2  \
# 0  Um dos livros faltam mais de 40 páginas. Ex.: ...         NaN         NaN
# 1  O livro é incompleto. Acaba em 11/04/44, sendo...         NaN         NaN
# 2  Ainda não terminei, estou nos 40%, devo ler em...         NaN         NaN
# 3  Pedi o livro baseado na promoção q era de graç...         NaN         NaN
# 4  Prezados, Acredito que houve um erro, pois des...         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  ...  Unnamed: 87  Unnamed: 88  Unnamed: 89  Unnamed: 90  \
# 0         NaN  ...          NaN          NaN          NaN          NaN
# 1         NaN  ...          NaN          NaN          NaN          NaN
# 2         NaN  ...          NaN          NaN          NaN          NaN
# 3         NaN  ...          NaN          NaN          NaN          NaN
# 4         NaN  ...          NaN          NaN          NaN          NaN
#
#    Unnamed: 91  Unnamed: 92  Unnamed: 93  Unnamed: 94  Unnamed: 95    Target
# 0          NaN          NaN          NaN          NaN          NaN   entrega
# 1          NaN          NaN          NaN          NaN          NaN   entrega
# 2          NaN          NaN          NaN          NaN          NaN  conteúdo
# 3          NaN          NaN          NaN          NaN          NaN   entrega
# 4          NaN          NaN          NaN          NaN          NaN   entrega
#
# [5 rows x 97 columns]

# %%
test = pd.read_excel('dados_teste.xlsx')
test.head(5)
# Out:
#                                             Mensagem  Unnamed: 1  Unnamed: 2  \
# 0  a narrativa é muito lenta e você fica ansioso ...         NaN         NaN
# 1  Sim.adorei o livro Vou continuar a comprar o r...         NaN         NaN
# 2  Desculpem, mas achei deprimente e não me ensin...         NaN         NaN
# 3  Preciso saber se essa compra é do livro físico...         NaN         NaN
# 4  Embora tenha gostado do livro "Não Faz Sentido...         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  ...  Unnamed: 33  Unnamed: 34  Unnamed: 35 Unnamed: 36  \
# 0         NaN  ...          NaN          NaN          NaN         NaN
# 1         NaN  ...          NaN          NaN          NaN         NaN
# 2         NaN  ...          NaN          NaN          NaN         NaN
# 3         NaN  ...          NaN          NaN          NaN         NaN
# 4         NaN  ...          NaN          NaN          NaN         NaN
#
#    Unnamed: 37  Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41    Target
# 0          NaN          NaN          NaN          NaN          NaN  conteúdo
# 1          NaN          NaN          NaN          NaN          NaN  conteúdo
# 2          NaN          NaN          NaN          NaN          NaN  conteúdo
# 3          NaN          NaN          NaN          NaN          NaN   entrega
# 4          NaN          NaN          NaN          NaN          NaN  conteúdo
#
# [5 rows x 43 columns]

# %% [markdown]
# ___
# ## Classificador automático

# %% [markdown]
# Faça aqui uma descrição do seu assunto e o que considerou como relevante ou não relevante na classificação dos tweets (Target).
#
# ESCREVA AQUI...

# %% [markdown]
# ___
# ### Montando um Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %%
df_train = train['Mensagem'].to_frame()
df_train['Target'] = train['Target']

df_test = test['Mensagem'].to_frame()
df_test['Target'] = test['Target']

# %%
caracteres = [':',',','.','(',')', '?', '!', '"']
i = 0
for msg in df_train.Mensagem:
    for caractere in caracteres:
        if caractere in msg:
            msg = msg.replace(caractere, '')
            msg = msg.lower()
    df_train.loc[i, 'Mensagem'] = msg 
    i += 1
    
    
j = 0
for msg in df_test.Mensagem:
    for caractere in caracteres:
        if caractere in msg:
            msg = msg.replace(caractere, '')
            msg = msg.lower()
    df_test.loc[j, 'Mensagem'] = msg 
    j += 1

# %%
df_train.head(5)
# Out:
#                                             Mensagem    Target
# 0  um dos livros faltam mais de 40 páginas ex pul...   entrega
# 1  o livro é incompleto acaba em 11/04/44 sendo q...   entrega
# 2  ainda não terminei estou nos 40% devo ler em m...  conteúdo
# 3  pedi o livro baseado na promoção q era de graç...   entrega
# 4  prezados acredito que houve um erro pois desco...   entrega

# %%
df_test.head(5)
# Out:
#                                             Mensagem    Target
# 0  a narrativa é muito lenta e você fica ansioso ...  conteúdo
# 1  simadorei o livro vou continuar a comprar o re...  conteúdo
# 2  desculpem mas achei deprimente e não me ensino...  conteúdo
# 3  preciso saber se essa compra é do livro físico...   entrega
# 4  embora tenha gostado do livro não faz sentido ...  conteúdo

# %% [markdown]
# ___
# ### Verificando a performance do Classificador
#
# Agora você deve testar o seu classificador com a base de Testes.

# %%
lista_mensagem_teste = pd.Series(df_test.Mensagem)

lista_dos_splits = []
for msg in lista_mensagem_teste:
        for palavra in msg.split():
            lista_dos_splits.append(palavra)


universo = list(set(lista_dos_splits))


print(universo)

print(len(universo))
# Out:
# ['insistiram', 'mesma', 'atento', 'amazoncom', 'entediou', 'aquela', 'descompensadas', 'momentos', 'aquisição', 'espantoso', 'globais', 'objetivo', 'elementos', 'especulativos', 'elas', 'blog', 'roteiro', 'sozinha', 'insucesso', 'costumam', 'capítulo', 'infantis', 'à', 'quietos', 'ponto', 'continuaçao', 'formas', 'prendeu', 'deu', 'treinar', 'própria', 'abaixarem', 'manipular', 'roubou', 'pensem', 'encalhado', 'chances', 'útil', 'preciso', 'infiel', 'família', 'cartões', 'segunda', 'prometeu', 'merda', 'contagiado', 'thorne', 'incorreto', 'manjadas', 'ciência', 'fonte', 'maisnao', 'valeu', 'gostar', 'acabaria', 'tá', 'dores', 'establishment', 'petitiivas', 'democracia', 'irritar', 'milhões', 'adoraria', 'evolucionista', 'absoluto', 'sem', 'igual', 'indo', 'embrulho', 'nazistas', 'vi', 'telefone', 'viva', 'declaração', 'ideal', 'lento', 'xavier', 'ordem', 'tentando', 'francês', 'obra', 'questão', 'contraponto', 'teatro', 'exemplificar', 'aprender', 'evaa', 'estiver', 'então', 'continuei', 'reembolso', 'surreal', 'cancelar', 'riqueza', 'versão', 'intangível', 'critério', 'submarino', 'piada', 'ouviram', 'correta', 'tente', 'entrevista', 'subliminares', 'nós', 'há', 'justificativa', 'mel', '40%', 'comigo', 'esse', 'books', 'sérios', 'rasgadas', 'vomitando', 'possivel', 'agrada', 'esquerda', 'astral', 'linguagem', 'acrescento', 'design', 'explora', 'baixa', 'planeta', 'formador', 'processo', 'casal', 'percebemos', 'verdadeira', 'espelho', 'ateísmo', 'coma', 'manhã', 'achei', 'concessões', 'estragada', 'faturas', 'superior', 'direto', 'marca', 'trata-se', 'finalmente', 'conseguem', 'historiadores', 'baseando', 'vezespara', 'invisíveis', 'acabou', 'errados', 'palavra', 'liga', 'morreu', 'pedem', 'bonitos', 'enredo', 'orelhas', 'num', 'enfim', 'batalha', 'partir', 'engano', 'achar', 'capas', 'governos', 'sexuais', 'entendo', 'monótono', 'argumentação', 'esses', 'poemas', 'respeito', 'romance', 'revolução', 'homem', 'biografia', 'valores', 'nesse', 'douradas', 'contatar', 'situações', 'pagina', 'O', 'compadrios', 'frente', 'perda', 'ficam', 'sobrepor', 'tranquilamente', 'day', 'e-mail', 'aceitarem', 'uso', 'tem', 'lugares', 'décadas', 'inúmeras', 'horror', 'casa', 'acabamento', 'neologismos', 'linguajar', 'repetindo', 'amassada', 'empregas', 'suportamos', 'idealização', 'mandaram', 'resto', 'opinião/experiência', 'tomar', 'porta', 'espaçamento', 'pautas', 'all', 'paciência', 'última', 'prefácio', 'incrivelmente', 'dúvida', 'bagaça', 'narrativa', 'gosto', 'vende', 'compromisso', 'drasticamente', 'representa', 'daenerys', 'pronunciar', 'dela', 'concretizarãok', 'sexo', 'interminadoesperamos', 'amaram', 'pela', 'orgulho', 'mal', 'legado', 'importando', 'sentido', 'historiador', 'cer', 'captado', 'mesquinho', 'democracias', 'homens', 'jacket', 'embalados', 'robbins', 'capa', 'chamativo', 'quase', 'troca', 'deprimente', 'unavailable', 'massas', 'reiterando', 'r$12000', 'formatada', 'argumentos', 'leia-se', 'ficando', 'regra', 'formatacao', 'tinta', 'cansativa', 'deteriorar', 'instrutivo', 'flutua', 'carros', 'alberto', 'exploram', 'mudança', 'acabar', 'após', 'ridícula', 'fábrica', 'medos', 'danificado', 'or', 'sujos', 'academicamente', 'estante', 'pontas', 'acabei', 'retrato', 'fosse', 'seguinte', 'vidro', 'geral', 'misturou', 'agricultores', 'criada', 'criadas', 'empoeirados', 'atrapalha', 'casoinfelizmente', 'decepciona', 'inserindo', 'pior', 'expressar', 'encomendei', 'deficiências', 'tolo', 'berço', 'saraivapois', 'mês', 'populações', 'jack', 'cauxa', 'livro', 'falta', 'alem', 'distorce', 'única', 'comprando', 'cortadas', 'setor', 'desenvolvidos', 'positivas', 'cristã', 'próprias', 'amareladas', 'difícil', 'continuarei', 'esconde', 'quatro', 'equivocada', 'ebooks', 'viés', 'esquecendo', 'modificados', 'básico', 'pal-avras', 'metáforas', 'ditador', 'embarcar', 'decepcionaram', 'compreendido', 'lombada', 'às', 'maldigo', 'transparentes', 'disse', 'atendeu', 'demasiadamente', 'porque', 'deparo', 'ensinou', 'previamente', 'até', 'combo',  ...
# 3291

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# ___
# ### Qualidade do Classificador a partir de novas separações dos tweets entre Treinamento e Teste
#
# Caso for fazer esse item do Projeto

# %% [markdown]
# ___
# ## Aperfeiçoamento:
#
# Trabalhos que conseguirem pelo menos conceito B vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * IMPLEMENTOU outras limpezas e transformações que não afetem a qualidade da informação contida nos tweets. Ex: stemming, lemmatization, stopwords
# * CONSIDEROU mais de duas categorias na variável Target e INCREMENTOU a quantidade de notícias, mantendo pelo menos 250 notícias por categoria (OBRIGATÓRIO PARA TRIOS, sem contar como item avançado)
# * Para Target com duas categorias: CRIOU pelo menos quatro categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante
# * EXPLICOU porquê não pode usar o próprio classificador para gerar mais amostras de treinamento
# * PROPÔS diferentes cenários para Naïve Bayes fora do contexto do projeto (pelo menos dois cenários, exceto aqueles já apresentados em sala pelos professores: por exemplo, filtro de spam)
# * SUGERIU e EXPLICOU melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)
# * FEZ o item Qualidade do Classificador a partir de novas separações das Notícias entre Treinamento e Teste descrito no enunciado do projeto (OBRIGATÓRIO para conceitos A ou A+)

# %% [markdown]
# ___
# ## Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
