# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Caio Monteiro Marquez Barbosa
# Felipe Bakowski Nantes de Souza
# Lucas Santos Teixeira

# %% [markdown]
# Atenção: Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# Carregando algumas bibliotecas:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# c:\Users\caioj\OneDrive - Insper - Institudo de Ensino e Pesquisa\2 semestre\C. Dados\projeto 1\CdaDos_P1

# %% [markdown]
# Carregando a base de dados com os tweets classificados manualmente:

# %%
train = pd.read_excel('dados_treino.xlsx')
train.head(5)
# Out:
#                                             Mensagem  Unnamed: 1  Unnamed: 2  \
# 0  Um dos livros faltam mais de 40 páginas. Ex.: ...         NaN         NaN
# 1  O livro é incompleto. Acaba em 11/04/44, sendo...         NaN         NaN
# 2  Ainda não terminei, estou nos 40%, devo ler em...         NaN         NaN
# 3  Pedi o livro baseado na promoção q era de graç...         NaN         NaN
# 4  Prezados, Acredito que houve um erro, pois des...         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  ...  Unnamed: 87  Unnamed: 88  Unnamed: 89  Unnamed: 90  \
# 0         NaN  ...          NaN          NaN          NaN          NaN
# 1         NaN  ...          NaN          NaN          NaN          NaN
# 2         NaN  ...          NaN          NaN          NaN          NaN
# 3         NaN  ...          NaN          NaN          NaN          NaN
# 4         NaN  ...          NaN          NaN          NaN          NaN
#
#    Unnamed: 91  Unnamed: 92  Unnamed: 93  Unnamed: 94  Unnamed: 95    Target
# 0          NaN          NaN          NaN          NaN          NaN   entrega
# 1          NaN          NaN          NaN          NaN          NaN   entrega
# 2          NaN          NaN          NaN          NaN          NaN  conteúdo
# 3          NaN          NaN          NaN          NaN          NaN   entrega
# 4          NaN          NaN          NaN          NaN          NaN   entrega
#
# [5 rows x 97 columns]

# %%
test = pd.read_excel('dados_teste.xlsx')
test.head(5)
# Out:
#                                             Mensagem  Unnamed: 1  Unnamed: 2  \
# 0  a narrativa é muito lenta e você fica ansioso ...         NaN         NaN
# 1  Sim.adorei o livro Vou continuar a comprar o r...         NaN         NaN
# 2  Desculpem, mas achei deprimente e não me ensin...         NaN         NaN
# 3  Preciso saber se essa compra é do livro físico...         NaN         NaN
# 4  Embora tenha gostado do livro "Não Faz Sentido...         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  ...  Unnamed: 33  Unnamed: 34  Unnamed: 35 Unnamed: 36  \
# 0         NaN  ...          NaN          NaN          NaN         NaN
# 1         NaN  ...          NaN          NaN          NaN         NaN
# 2         NaN  ...          NaN          NaN          NaN         NaN
# 3         NaN  ...          NaN          NaN          NaN         NaN
# 4         NaN  ...          NaN          NaN          NaN         NaN
#
#    Unnamed: 37  Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41    Target
# 0          NaN          NaN          NaN          NaN          NaN  conteúdo
# 1          NaN          NaN          NaN          NaN          NaN  conteúdo
# 2          NaN          NaN          NaN          NaN          NaN  conteúdo
# 3          NaN          NaN          NaN          NaN          NaN   entrega
# 4          NaN          NaN          NaN          NaN          NaN  conteúdo
#
# [5 rows x 43 columns]

# %% [markdown]
# ___
# ## Classificador automático

# %% [markdown]
# Faça aqui uma descrição do seu assunto e o que considerou como relevante ou não relevante na classificação dos tweets (Target).
#
# ESCREVA AQUI...

# %% [markdown]
# ___
# ### Montando um Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %%
df_train = train['Mensagem'].to_frame()
df_train['Target'] = train['Target']

df_test = test['Mensagem'].to_frame()
df_test['Target'] = test['Target']

# %%
caracteres = [':',',','.','(',')', '?', '!', '"']
i = 0
for msg in df_train.Mensagem:
    for caractere in caracteres:
        if caractere in msg:
            msg = msg.replace(caractere, '')
            msg = msg.lower()
    df_train.loc[i, 'Mensagem'] = msg 
    i += 1
    
    
j = 0
for msg in df_test.Mensagem:
    for caractere in caracteres:
        if caractere in msg:
            msg = msg.replace(caractere, '')
            msg = msg.lower()
    df_test.loc[j, 'Mensagem'] = msg 
    j += 1

# %%
df_train.head(5)
# Out:
#                                             Mensagem    Target
# 0  um dos livros faltam mais de 40 páginas ex pul...   entrega
# 1  o livro é incompleto acaba em 11/04/44 sendo q...   entrega
# 2  ainda não terminei estou nos 40% devo ler em m...  conteúdo
# 3  pedi o livro baseado na promoção q era de graç...   entrega
# 4  prezados acredito que houve um erro pois desco...   entrega

# %%
df_test.head(5)
# Out:
#                                             Mensagem    Target
# 0  a narrativa é muito lenta e você fica ansioso ...  conteúdo
# 1  simadorei o livro vou continuar a comprar o re...  conteúdo
# 2  desculpem mas achei deprimente e não me ensino...  conteúdo
# 3  preciso saber se essa compra é do livro físico...   entrega
# 4  embora tenha gostado do livro não faz sentido ...  conteúdo

# %%
livro_conteudo = ''
df_train_conteudo = df_train.loc[(df_train.Target == 'conteúdo')]
for msg in df_train_conteudo.Mensagem:
    livro_conteudo +=msg

livro_entrega = ''
df_train_entrega = df_train.loc[(df_train.Target == 'entrega')]
for msg in df_train_entrega.Mensagem:
    livro_entrega += msg

livro_geral = livro_entrega + livro_conteudo

# %% [markdown]
# ___
# ### Verificando a performance do Classificador
#
# Agora você deve testar o seu classificador com a base de Testes.

# %%
lista_mensagem_treino = pd.Series(df_train.Mensagem)

lista_dos_splits = []
for msg in lista_mensagem_treino:
        for palavra in msg.split():
            lista_dos_splits.append(palavra)


universo = list(set(lista_dos_splits))


print(universo)

print(len(universo))
# Out:
# ['soltasa', 'chegam', 'brutalidade', 'precisei', 'explica', '“literatura”', 'perspectivas', 'linkhttps//youtube/ejq9kvvuw0y', 'incrivelmente', 'filmes', 'página', 'menções', 'vendas', 'obvio', 'nacional', 'própria', 'influenciáveis', 'green', 'brilhante', 'editora', 'regra', 'pressuposto', 'amei', 'defeitos', 'suja', 'embasamento', 'passaram', 'gostar', 'aparato', 'considerado', 'responsável', 'versões', 'status', 'férias', 'boxes', 'encarada', 'falando', 'vinha', 'cola', 'comum', 'cansei', 'preocupante', 'série', 'outras', 'karla', 'leve', 'moças', 'sessenta', 'publicação', 'aluno', 'feitos', 'gustave', 'descolamento', 'madre', 'semanas', 'cosmologia', 'desnecessáriasum', 'resolva', 'avisar', 'absurdo', 'imbecilidade', 'saindo', 'ensinado', 'olavo', 'manada', 'indução', 'conselhos', 'compartilhando', 'disposto', 'etc', 'gosto', 'prejudicaram', 'importantes', 'acadêmico', 'desviosetc', 'monótono', 'bonitas', 'tecnologia', 'adultas', 'centristas', 'narrativa', 'ranzinza', 'sejam', 'comercializar', 'detonada', 'problemas', 'unica', 'barbárie', 'max', 'O', 'ué', 'fantasias', 'alfa', 'amzon', 'traz', 'distorce', 'agrade', 'recebida', 'cabível', 'maria', 'crédito', 'historiador', 'fina', 'falácias', 'os', '4a', 'faculdade', 'abaixo', 'fossem', 'alcançar', 'veja', 'fique', 'ganho', 'marca', 'teatro', 'douradas', 'agua', 'território', 'comparei', 'compiladas', 'descobri', 'bem-estar', 'ignorante', 'extraviado', 'ganhei', 'justificasse', 'anotar', 'heisenberg', 'gratuita', 'pedaços', 'conclusão', 'dela', 'tento', 'adapta', 'chega', 'afixada', 'réplica', 'acontecido', 'curtir', 'livre', 'erroneamente', 'sempre', 'reclamou', 'filha', 'destrutivas', 'maisnão', 'destópica', 'horriveis', 'quer', 'posto', 'brasileiros', 'banheiro', 'preto', 'mês', 'tomando', 'judéuse', 'interações', 'cobrado', 'continue', 'tenham', 'efetuar', 'mta', 'dali', 'grandes', 'significa', 'amamossp', 'ninguém', 'voltarei', 'disponibilizado', 'cálice', 'corrige', 'fundamento', 'circo;', 'crise', 'rapidamente', 'psíquica', 'trecho', '500', 'segurando', 'desenvolvam', 'coletora', 'cedendo', 'auto-ajudas', 'tristes', 'honestamente', 'constam', 'extrema-direita', 'assíduo', 'normal', 'repete', 'aventurar', 'interrompesse', 'impressoes', 'mimada', 'morais', 'foge', 'possivel', 'amazon', 'amareladas', 'foco', 'suficiente', 'embasamento;', 'bonitos', 'linhasde', 'investigativa', 'animado', 'sou', "n'água", 'gangs;', 'livros', 'painão', 'trump', 'colégios', 'partidos', 'segredo', 'cobrar', 'difícil', 'acho', 'fundamental', 'reembolsaram', 'cheias', 'historias', 'surpresa', 'entendimento', 'sobrinha', 'acontece', 'filão', 'dada', 'endereço', 'ver', 'saborosa', 'rasgado', 'barata', 'publicadas', '8000', 'jeito', 'expressar', 'russa', 'porcentagem', 'identificar', 'claros', 'estoque', 'afiados', 'isso', 'históricas', 'esclarece', 'palerma', 'austen', 'fortes', 'pouco', 'conservados', 'enfrentamos', 'instituído', 'jesus', 'reconhecer', 'tais', 'naquele', 'interminável', 'nenhuma', 'preocupa', 'teor', 'condições', 'soubesse', 'portanto', 'convence', 'ideal', 'intelectual', 'violento', 'mercantil', 'lançado', 'mídia', 'pessoais', 'lavagem', 'danfe', 'hal', 'trechos', 'respectivos', 'usados', 'produto', 'conflito', 'gratuito', 'animais', 'vcs', 'reentregar', 'anticomunista', 'evolucionistas', 'acha', 'excessivasisso', 'imatura', 'antecipadamente', 'abertamente', 'mudadas', 'derivativo', 'desprezem', 'pitadinhas', '35%', 'convertido', 'bisonho', 'generalistas', 'senti', 'semelhança', 'mesquinha', 'amadurecer', 'ostensivamente', 'trajetória', 'incapacidade', 'fúteis', 'seguir', 'alheia', 'pequenas', 'ia', "'autora'", 'citações', 'doenças', 'ai', 'velhoarrogante', 'assustadora', 'nossa', 'simultâneos', 'sobre', 'publicar', 'ficção', 'responde', 'agnósticos', 'brochura', 'defender', 'atrofiar', 'dória', 'devo', 'pensaria', 'hoje', 'guerra', 'desesperados', 'estados', 'rotuladas', 'desvelar', 'trem', 'teve', 'fingi', 'pediu', 'editor', 'céticos', 'didáticos', 'esses', 'poucas', 'exclui ...
# 5097

# %%
#suavização de laplace
frequencia_suavizada = dict()
serie_geral = pd.Series(livro_geral.split())
tabela_geral = serie_geral.value_counts(True)
tabela_geral

serie_conteudo = pd.Series(livro_conteudo.split())
tabela_conteudo = serie_conteudo.value_counts(True)
tabela_conteudo

serie_entrega = pd.Series(livro_entrega.split())
tabela_entrega = serie_entrega.value_counts(True)
tabela_entrega



for palavra in livro_geral.split():
    D = len(livro_geral.split()) + len(universo)
    N = tabela_geral[palavra] + 1
    if palavra not in frequencia_suavizada:
        frequencia_suavizada[palavra] = N/D

    else:
        frequencia_suavizada[palavra] +=N/D

# %%
prob_entrega = len(serie_entrega)/len(serie_geral)
prob_conteudo = len(serie_conteudo)/len(serie_geral)

lista_frases_teste = []
for frase in df_test['Mensagem']:
    lista_frases_teste.append(frase.split())

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# ___
# ### Qualidade do Classificador a partir de novas separações dos tweets entre Treinamento e Teste
#
# Caso for fazer esse item do Projeto

# %% [markdown]
# ___
# ## Aperfeiçoamento:
#
# Trabalhos que conseguirem pelo menos conceito B vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * IMPLEMENTOU outras limpezas e transformações que não afetem a qualidade da informação contida nos tweets. Ex: stemming, lemmatization, stopwords
# * CONSIDEROU mais de duas categorias na variável Target e INCREMENTOU a quantidade de notícias, mantendo pelo menos 250 notícias por categoria (OBRIGATÓRIO PARA TRIOS, sem contar como item avançado)
# * Para Target com duas categorias: CRIOU pelo menos quatro categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante
# * EXPLICOU porquê não pode usar o próprio classificador para gerar mais amostras de treinamento
# * PROPÔS diferentes cenários para Naïve Bayes fora do contexto do projeto (pelo menos dois cenários, exceto aqueles já apresentados em sala pelos professores: por exemplo, filtro de spam)
# * SUGERIU e EXPLICOU melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)
# * FEZ o item Qualidade do Classificador a partir de novas separações das Notícias entre Treinamento e Teste descrito no enunciado do projeto (OBRIGATÓRIO para conceitos A ou A+)

# %% [markdown]
# ___
# ## Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
